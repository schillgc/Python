# %% [markdown]
# # STUDY OF U.S. MASS SCHOOL SHOOTINGS
# ## By: Gavin Schilling

# %% [markdown]
# ### Introduction
#
# While there are records of instances of school shootings in the United States dating back to the Enoch Brown school massacre in Greencastle, PA on July 26, 1764, the first mass school shooting according to the modern convention of counting a mass school shooting as being a three person or more casualty on the actual school grounds did not occur until March 26, 1893 in Plain Dealing, LA during an evening dance at the school.  According to Wikipedia between then and 1966 only three other mass school shootings occurred.  They were as follows:
#
# * The December 13, 1898 Charleston, WV school exhibition incident killing 6 and wounding at least 1 other
# * The May 6, 1940 Pasadena, CA - South Pasadena Junior High School - murders leaving 5 dead and 2 others wounded
# * The February 2, 1960 Hartford City, IN - William Reed School - shooting killing 3
#
# This means that only four modern day standard mass school shootings occurred before 1966 even though around 130 school-related shootings are on record with Wikipedia from this early time period in America history.  Thankfully, the rest of these horrific events do not meet the modern definition of being a mass school shooting by today's standards as outlined above.
#
# In 1968 & 1970, a total of 9 student protesters were killed and another 48 were injured at the hands of United States government officers.  Those two years the following three major mass incidents occurred included the disgraceful South Carolina State University racist protesters in Orangeburg, SC on February 8, 1968, the Kent State University Vietnam War protesters being gunned down by armed National Guard solders on May 4, 1970 in Kent, OH, and when the police shot the protestors at the Jackson State University in Jackson, MS over the United States' military presence in Cambodia on May 15, 1970 (occurring only eleven days following the Kent State massacre).
#
# While, the Columbine High School massacre did not happen until 1999, these attacks by the United States government and the August 1, 1966 University of Texas - Austin massacre in Austin, Texas killing 17 and wounding 31 paired with the November 12, 1966 (roughly 3.5 months after the University of Texas massacre) in Mesa, AZ where 5 died and another 2 were injured, set off a new type of shock value for the vast increase number killed in any particular incident.
#
# Now, in the first month and a half of 2018, the United States not only has had the deadliest mass school shooting in United States history, but has had the school shooting rate increase to 1 occurring in every 60 hours.  Many National Rifle Association (NRA) backed politicians continue to look the other way or actively try to stall any and all gun-control reform or legislation.

# %% [markdown]
# ### Hypothesis
#
# While it is clear that gun violence is not possible without guns, the interpretation of the *Second Amendment* of *The Bill of Rights* to the *United States Constitution* protects at least some of her citizens to bare arms under certain well-regulated circumstances as follows: "A well regulated Militia, being necessary to the security of a free State, the right of the people to keep and bear Arms, shall not be infringed."  These restriction of being first well-regulated, governed under a lawful collective body, and being protected only at times of necessity of securing a free State not only is the law, but also there in this the Founders brilliance which lies both the pearls of wisdom and the rub as to any ambiguity.  It is clear from the wording of this amendment verses all the others to-date that the Founders signing the Constitution clearly intended it to have breathing room in case of a foreign invasion, civil war, hunting, or any other communal benefit as described by the federal or local government as it is their most basic duty to The People to protect and defend the country and all her citizens.
#
# Having said that, I believe we as a society have run a stray regarding gun mentality.  In the days of the "Wild West," salon and high noon shootouts occurred far too frequently.  As did armed bandits, robbers, and criminal behaviors we have tried desperately to outlaw ever since including from the 1920 mobster crime family sprees -- sometimes to what appears no to little avail.  That having been said, the **National Rifle Association (NRA)** has over extended its duties to protect the 2nd Amendment, and has in the words of my former professor and Noble Prize winner, Noam Chomsky, created an illegal "Profit Over People" enterprise.  Under the current state of the NRA, politicians (mostly Republican) have been bought off by this special interest group with campaign contributions, bribes, and disinformation campaigns as reported by most of the world's most major media news outlets.
#
# Therefore, ***it is my intention to look into these claims and see if the data shows increases of mass gun violence in either low gun control states or in states where U.S. congressional members' NRA ratings are higher.***  If this data does show this then the legislative solution might favor changes to states alone on a state-by-state basis.  If not, the data might then mean that due to being a free interstate society that stricter gun laws must come top down from the Federal government in order to solve the gun violence epidemic sweeping every state of the country.  One thing is for certain, change can not come fast enough, but over regulation historically leads to an increase in crime and eventual reversal of sensability.

# %% [markdown]
# ### Procedures
#
# First, as a best practice we import our required libraries at the top of a file (both for easy access and documenting reference; as well as, for the functional purpose of ensuring the file has been properly loaded prior to any need within the program itself).

# %%
# Import Libraries

# %matplotlib inline

from csv import DictReader
from http import HTTPStatus
from io import BytesIO
from json import loads
from sqlite3 import connect, Error
from urllib.request import build_opener, urlopen
from zipfile import ZipFile

import matplotlib.pyplot as plt
import pandas as pd
import requests
from bs4 import BeautifulSoup
from openpyxl import load_workbook

# %% [markdown]
# Next, let's retrieve the first dataset necessary for the project via the internet -- the *Stanford MSA Database*.

# %%
# Unzip Stanford MSA Database CSV file

msa_url = "https://stanford.box.com/shared/static/75lmj9rvw9mhtfqfjijhcc6oa15o5m4a.zip"
open_msa_url = urlopen(msa_url)
msa_zipped = ZipFile(BytesIO(open_msa_url.read()))
msa_zipped.extractall('store')
msa_zipped.namelist() # Proves proper connection occured
print("Zip File List: \n", msa_zipped.filelist)
msa_zipped.close()
# Out:
# Zip File List:
#  [<ZipInfo filename='MSA/' filemode='drwxr-xr-x' external_attr=0x4000>, <ZipInfo filename='MSA/Stanford_MSA_Data_Dictionary (V.5).pdf' compress_type=deflate filemode='-rw-r--r--' external_attr=0x4000 file_size=423971 compress_size=371098>, <ZipInfo filename='__MACOSX/' filemode='drwxrwxr-x' external_attr=0x4000>, <ZipInfo filename='__MACOSX/MSA/' filemode='drwxrwxr-x' external_attr=0x4000>, <ZipInfo filename='__MACOSX/MSA/._Stanford_MSA_Data_Dictionary (V.5).pdf' compress_type=deflate filemode='-rw-r--r--' external_attr=0x4000 file_size=181 compress_size=102>, <ZipInfo filename='MSA/Stanford_MSA_Database_for_release_06142016.xlsx' compress_type=deflate filemode='-rw-r--r--' external_attr=0x4000 file_size=519599 compress_size=399034>, <ZipInfo filename='__MACOSX/MSA/._Stanford_MSA_Database_for_release_06142016.xlsx' compress_type=deflate filemode='-rw-r--r--' external_attr=0x4000 file_size=181 compress_size=102>]

# %% [markdown]
# Now lets transverse the virtual file structure to the appropriate worksheet.

# %%
# Load Workbook & Proper Worksheet

try:
    workbook = load_workbook('store/MSA/Stanford_MSA_Database_for_release_06142016.xlsx')
    worksheet = workbook.active
    HTTPStatus.OK.description

    print("Workbook Path: \n", workbook.path, "\n")
    print("Active Worksheet: \n", worksheet)

except Error as error:
    print("Error: \n", error)
# Out:
# Workbook Path:
#  /xl/workbook.xml
#
# Active Worksheet:
#  <Worksheet "Published">

# %% [markdown]
# Now lets create the SQL database connection.

# %%
# Create a SQL database connection

DB_FILE = 'temp/mass_shootings.db'

conn = connect(DB_FILE)
print("SQL Connection: \n", conn, "\n")     # Proof of Creation

conn.text_factory = str
print("Conn Text Factory: \n", conn.text_factory, "\n")

c = conn.cursor()
print("Cursor 1: \n", c.arraysize, "\n")    # Proof of Creation

table_name = "Shootings"
print("Table Name: \n", table_name)
# Out:
# SQL Connection:
#  <sqlite3.Connection object at 0x000000000A64DC70>
#
# Conn Text Factory:
#  <class 'str'>
#
# Cursor 1:
#  1
#
# Table Name:
#  Shootings

# %%
# Read Streamed Excel file

df_msa_xls = pd.read_excel('store/MSA/Stanford_MSA_Database_for_release_06142016.xlsx',
                           'Published',
                           index_col='CaseID')
print("MSA XLS: \n", df_msa_xls)
# msv_cvs = msa_xls.to_csv('store/MSA/Stanford_MSA_Database_for_release.csv', encoding='utf-8', index=False)
# Out:
# MSA XLS:
#                                                Title  \
# CaseID
# 1                     University of Texas at Austin
# 2                        Rose-Mar College of Beauty
# 3                      New Orleans Police Shootings
# 4                    Clara Barton Elementary School
# 5                                 Olean High School
# 6              Los Angeles Computer Learning Center
# 7                               Cal State Fullerton
# 8                Grover Cleveland Elementary School
# 9                      University of South Carolina
# 10                               Valley High School
# 11                            Welding shop in Miami
# 12                          Wah Mee Club in Seattle
# 13                             Johnston Post Office
# 14                    49th Street Elementary School
# 15                           Ianni's Club in Dallas
# 16              McDonald's restaurant in San Ysidro
# 17                       Goddard Junior High School
# 18                              Atlanta Post Office
# 19                       New York Technical College
# 20                  Post office in Edmond, Oklahoma
# 21                        Fergus County High School
# 22                        Palm Bay Shopping Centers
# 23                        Pinellas Park High School
# 24         Electromagnetic Systems Laboratory (ESL)
# 25                  Hubbard Woods Elementary School
# 26           Comet Auto Parts and Montefiore School
# 27                        Oakland Elementary School
# 28                 New Orleans Downtown Post Office
# 29                      Cleveland Elementary School
# 30                         Orange Glenn Post Office
# ...                                             ...
# 287                     Detroit Strip Club Shootout
# 288                   Riverside restaurant shooting
# 289                      Wichita Nightclub shooting
# 290      Chelsea, MA empty apartment party shooting
# 291                     Roswell, GA Hookah shootout
# 292                          Lafayette, LA drive by
# 293                       Kansas City Home Invasion
# 294                Wilkinsburg BBQ cookout shootout
# 295                   Trenton, NJ sidewalk shooting
# 296                                Detroit Drive-by
# 297                Elberton, Georgia murder-suicide
# 298     Florida Family celebration ends in shooting
# 299                      Atlanta Nightclub shooting
# 300                               Wetumpka Drive-by
# 301                     Spring Break Party shooting
# 302            Louisville, KY Family Murder-Suicide
# 303               Sherman, TX Family murder-suicide
# 304             Greenhill, AL Family murder-suicide
# 305      Albuquerque, NM Family restaurant shooting
# 306             Chicago Birthday Party Bus Shooting
# 307            Albuquerque, NM House party shooting
# 308                Memphis, TN gas station shooting
# 309                        Long Beach Street murder
# 310                      Chicago Rap video Shootout
# 311                     Texas family murder-suicide
# 312                 Alabama highway random shooting
# 313                Tire-Slashing revenge escalation
# 314                              Halifax County, VA
# 315                  Forestville, Maryland Drive-by
# 316                           Ferguson, MO Drive by
#
#                          Location           City           State   Latitude  \
# CaseID
# 1                   Austin, Texas         Austin           Texas  30.198887
# 2                   Mesa, Arizona           Mesa         Arizona  33.422687
# 3          New Orleans, Louisiana    New Orleans       Louisiana  30.068724
# 4               Chicago, Illinois        Chicago        Illinois  41.839280
# 5                 Olean, New York          Olean        New York  42.081854
# 6         Los Angeles, California    Los Angeles      California  34.176221
# 7           Fullerton, California      Fullerton      California  33.884042
# 8           San Diego, California      San Diego      California  32.863573
# 9        Columbia, South Carolina       Columbia  South Carolina  34.050988
# 10              Las Vegas, Nevada      Las Vegas          Nevada  36.189319
# 11                 Miami, Florida          Miami         Florida  25.796539
# 12            Seattle, Washington        Seattle      Washington  47.621996
# 13       Johnston, South Carolina       Johnston  South Carolina  33.832729
# 14        Los Angeles, California    Los Angeles      California  34.176221
# 15                  Dallas, Texas         Dallas           Texas  32.794806
# 16         San Ysidro, California     San Ysidro      California  32.555556
# 17                Goddard, Kansas        Goddard          Kansas  37.671294
# 18               Atlanta, Georgia        Atlanta         Georgia  33.762997
# 19             Brooklyn, New York       Brooklyn        New York  40.679276
# 20               Edmond, Oklahoma         Edmond        Oklahoma  35.668892
# 21             Lewistown, Montana      Lewistown         Montana  47.037407
# 22              Palm Bay, Florida       Palm Bay         Florida  27.983890
# 23         Pinellas Park, Florida  Pinellas Park         Florida  27.848871
# 24          Sunnyvale, California      Sunnyvale      California  37.383443
# 25             Winnetka, Illinois       Winnetka        Illinois  42.106488
# 26              Chicago, Illinois        Chicago        Illinois  41.839280
# 27      Greenwood, South Carolina      Greenwood  South Carolina  34.192895
# 28         New Orleans, Louisiana    New Orleans       Louisiana  30.068724
# 29           Stockton, California       Stockton      California  37.966318
# 30          Escondido, California      Escondido      California  33.134399
# ...                           ...            ...             ...        ...
# 287             Detroit, Michigan        Detroit        Michigan  42.331427
# 288     Jurupa Valley, California  Jurupa Valley      California  33.997197
# 289               Wichita, Kansas        Wichita          Kansas  37.687176
# 290        Chelsea, Massachusetts        Chelsea   Massachusetts  42.391764
# 291              Roswell, Georgia        Roswell         Georgia  34.023243
# 292          Lafayette, Louisiana      Lafayette       Louisiana  30.224090
# 293           Kansas City, Kansas    Kansas City          Kansas  39.114053
# 294     Wilkinsburg, Pennsylvania    Wilkinsburg    Pennsylvania  40.441736
# 295           Trenton, New Jersey        Trenton      New Jersey  40.217053
# 296             Detroit, Michigan        Detroit        Michigan  42.331427
# 297             Elberton, Georgia       Elberton         Georgia  34.111223
# 298           Fort Myers, Florida     Fort Myers         Florida  26.640628
# 299              Atlanta, Georgia        Atlanta         Georgia  33.748995
# 300             Wetumpka, Alabama       Wetumpka         Alabama  32.543745
# 301           Plantation, Florida     Plantation         Florida  26.127586
# 302          Louisville, Kentucky     Louisville        Kentucky  38.252665
# 303                Sherman, Texas        Sherman           Texas  33.635662
# 304            Greenhill, Alabama      Greenhill         Alabama  34.759257
# 305       Albuquerque, New Mexico    Albuquerque      New Mexico  35.085334
# 306             Chicago, Illinois        Chicago        Illinois  41.878114
# 307       Albuquerque, New Mexico    Albuquerque      New Mexico  35.085334
# 308            Memphis, Tennessee        Memphis       Tennessee  35.149534
# 309        Long Beach, California     Long Beach      California  33.770050
# 310             Chicago, Illinois        Chicago        Illinois  41.878114
# 311                   Katy, Texas           Katy           Texas  29.785785
# 312          Brooksville, Alabama    Brooksville         Alabama  34.162040
# 313           Baltimore, Maryland      Baltimore        Maryland  39.290385
# 314             Halifax, Virginia        Halifax        Virginia  36.765971
# 315         Forestville, Maryland    Forestville        Maryland  38.845113
# 316            Ferguson, Missouri       Ferguson        Missouri  38.744217
#
#          Longitude  Number of Victim Fatalities  Total Number of Fatalities  \
# CaseID
# 1       -97.844159                           16                          17
# 2      -111.816320                            5                           5
# 3       -89.931474                            9                          10
# 4       -87.688181                            1                           1
# 5       -78.432139                            3                           3
# 6      -118.539954                            1                           1
# 7      -117.927850                            7                           7
# 8      -117.128163                            2                           2
# 9       -80.820775                            2                           2
# 10     -115.326487                            1                           1
# 11      -80.208404                            8                           9
# 12     -122.323646                           13                          13
# 13      -81.805158                            1                           1
# 14     -118.539954                            2                           3
# 15      -96.766311                            6                           6
# 16     -117.047656                           21                          22
# 17      -97.550705                            1                           1
# 18      -84.423133                            2                           2
# 19      -73.939513                            1                           1
# 20      -97.414388                           14                          15
# 21     -109.484492                            1                           1
# 22      -80.666627                            6                           6
# 23      -82.710580                            1                           1
# 24     -122.025618                            7                           7
# 25      -87.742111                            1                           2
# 26      -87.688181                            4                           5
# 27      -82.153555                            2                           2
# 28      -89.931474                            0                           0
# 29     -121.301878                            5                           6
# 30     -117.072253                            3                           4
# ...            ...                          ...                         ...
# 287     -83.045754                            0                           0
# 288    -117.485480                            1                           1
# 289     -97.330053                            0                           0
# 290     -71.032828                            1                           1
# 291     -84.361556                            0                           0
# 292     -92.019843                            0                           0
# 293     -94.627464                            4                           4
# 294     -79.881994                            5                           5
# 295     -74.742938                            0                           0
# 296     -83.045754                            2                           2
# 297     -82.867084                            1                           2
# 298     -81.872308                            0                           0
# 299     -84.387982                            0                           0
# 300     -86.211913                            2                           2
# 301     -80.233104                            1                           1
# 302     -85.758456                            3                           4
# 303     -96.608880                            3                           4
# 304     -86.602493                            1                           2
# 305    -106.605553                            2                           3
# 306     -87.629798                            0                           0
# 307    -106.605553                            0                           0
# 308     -90.048980                            0                           0
# 309    -118.193739                            1                           0
# 310     -87.629798                            1                           1
# 311     -95.824396                            4                           4
# 312     -86.475543                            0                           1
# 313     -76.612189                            0                           0
# 314     -78.928344                            0                           0
# 315     -76.874972                            1                           1
# 316     -90.305391                            0                           0
#
#         Number of Victims Injured  Total Number of Victims  ...  \
# CaseID                                                      ...
# 1                              32                       48  ...
# 2                               1                        6  ...
# 3                              13                       22  ...
# 4                               3                        4  ...
# 5                               7                       10  ...
# 6                               7                        8  ...
# 7                               2                        9  ...
# 8                               9                       11  ...
# 9                               5                        7  ...
# 10                              2                        3  ...
# 11                              3                       11  ...
# 12                              1                       14  ...
# 13                              3                        4  ...
# 14                             12                       14  ...
# 15                              1                        7  ...
# 16                             19                       40  ...
# 17                              3                        4  ...
# 18                              1                        3  ...
# 19                              4                        5  ...
# 20                              6                       20  ...
# 21                              3                        4  ...
# 22                             14                       20  ...
# 23                              2                        3  ...
# 24                              4                       11  ...
# 25                              7                        8  ...
# 26                              2                        6  ...
# 27                              9                       11  ...
# 28                              4                        4  ...
# 29                             30                       35  ...
# 30                              1                        4  ...
# ...                           ...                      ...  ...
# 287                             5                        5  ...
# 288                             3                        4  ...
# 289                             4                        4  ...
# 290                             6                        7  ...
# 291                             4                        4  ...
# 292                             4                        4  ...
# 293                             0                        4  ...
# 294                             3                        8  ...
# 295                             5                        5  ...
# 296                             2                        4  ...
# 297                             2                        3  ...
# 298                             4                        4  ...
# 299                             4                        4  ...
# 300                             2                        4  ...
# 301                             4                        5  ...
# 302                             0                        3  ...
# 303                             0                        3  ...
# 304                             2                        3  ...
# 305                             1                        3  ...
# 306                             5                        5  ...
# 307                             4                        4  ...
# 308                             4                        4  ...
# 309                             3                        4  ...
# 310                             4                        5  ...
# 311                             0                        4  ...
# 312                             4                        4  ...
# 313                             4                        4  ...
# 314                             6                        6  ...
# 315                             4                        5  ...
# 316                             4                        4  ...
#
#        History of Mental Illness - General  \
# CaseID
# 1                                      Yes
# 2                                      Yes
# 3                                      Yes
# 4                                      Yes
# 5                                       No
# 6                                  Unknown
# 7                                      Yes
# 8                                      Yes
# 9                                  Unknown
# 10                                     Yes
# 11                                     Yes
# 12                                 Unknown
# 13                                     Yes
# 14                                     Yes
# 15                                     Yes
# 16                                     Yes
# 17                                     Yes
# 18                                     Yes
# 19                                     Yes
# 20                                     Yes
# 21                                     Yes
# 22                                     Yes
# 23                                      No
# 24                                     Yes
# 25                                     Yes
# 26                                      No
# 27                                     Yes
# 28                                 Unknown
# 29                                     Yes
# 30                                      No
# ...                                    ...
# 287                                Unknown
# 288                                Unknown
# 289                                Unknown
# 290                                Unknown
# 291                                Unknown
# 292                                Unknown
# 293                                Unknown
# 294                                Unknown
# 295                                Unknown
# 296                                Unknown
# 297                                Unknown
# 298                                Unknown
# 299                                Unknown
# 300                                Unknown
# 301                                Unknown
# 302                                    Yes
# 303                                Unknown
# 304                                    Yes
# 305                                Unknown
# 306                                Unknown
# 307                                Unknown
# 308                                Unknown
# 309                                Unknown
# 310                                Unknown
# 311                                Unknown
# 312                                    Yes
# 313                                Unknown
# 314                                Unknown
# 315                                Unknown
# 316                                Unknown
#
#                                             Data Source 1  \
# CaseID
# 1            http://en.wikipedia.org/wiki/Charles_Whitman
# 2       "Slaughter In The College Of Beauty." Time 88....
# 3       http://news.google.com/newspapers?nid=1144&dat...
# 4       http://news.google.com/newspapers?nid=1338&dat...
# 5       http://buffalo.ynn.com/content/top_stories/622...
# 6       http://news.google.com/newspapers?nid=1314&dat...
# 7       http://ranchosantamargarita.patch.com/articles...
# 8       http://www.utsandiego.com/news/2012/dec/14/loo...
# 9       http://news.google.com/newspapers?nid=1755&dat...
# 10      http://news.google.com/newspapers?id=CB4eAAAAI...
# 11      http://www.nytimes.com/1982/08/21/us/gunman-in...
# 12      http://www.historylink.org/index.cfm?DisplayPa...
# 13      http://www.alternet.org/story/24798/excerpt%3A...
# 14      http://www.nytimes.com/1984/02/25/us/girl-kill...
# 15      http://www.nycrimecommission.org/mass-shooting...
# 16      http://www.nycrimecommission.org/mass-shooting...
# 17      http://news.google.com/newspapers?nid=1345&dat...
# 18      http://articles.latimes.com/1985-03-07/news/mn...
# 19      http://www.nytimes.com/1986/08/16/nyregion/stu...
# 20      http://digital.library.okstate.edu/encyclopedi...
# 21      http://news.google.com/newspapers?nid=1734&dat...
# 22      http://www.floridacapitalcases.state.fl.us/cas...
# 23      http://articles.orlandosentinel.com/keyword/pi...
# 24      California Supreme Court documentation of the ...
# 25      http://www.nytimes.com/1988/05/22/us/police-st...
# 26      http://articles.chicagotribune.com/1988-09-23/...
# 27      http://www.nytimes.com/1988/09/28/us/man-held-...
# 28                 books.google.com/books?isbn=0398074321
# 29      http://www.nycrimecommission.org/initiative1-s...
# 30      http://articles.latimes.com/keyword/john-merli...
# ...                                                   ...
# 287     http://www.fox2detroit.com/news/local-news/987...
# 288     http://www.pe.com/articles/jurupa-795749-valle...
# 289     http://www.kake.com/home/headlines/Police-inve...
# 290     http://www.wcvb.com/news/7-shot-1-critical-in-...
# 291     http://patch.com/georgia/roswell/4-people-shot...
# 292     http://theadvocate.com/news/acadiana/15115322-...
# 293     http://www.kansascity.com/news/local/crime/art...
# 294     http://www.wpxi.com/news/da-says-community-saf...
# 295     http://www.trentonian.com/general-news/2016031...
# 296     http://www.detroitnews.com/story/news/local/de...
# 297     http://wspa.com/2016/03/13/murder-suicide-leav...
# 298     http://www.winknews.com/2016/03/13/source-guns...
# 299     http://newschannel9.com/news/nation-world/poli...
# 300     http://www.montgomeryadvertiser.com/story/news...
# 301     http://www.sun-sentinel.com/local/broward/plan...
# 302     http://www.cbsnews.com/news/4-dead-in-alleged-...
# 303     http://www.kxii.com/home/headlines/Sherman-sho...
# 304     http://www.timesdaily.com/news/crime/woman-kil...
# 305     http://www.abqjournal.com/750012/news/police-i...
# 306     http://abc7chicago.com/news/5-shot-on-party-bu...
# 307     http://www.abqjournal.com/754320/news/four-in-...
# 308     http://www.fox13memphis.com/news/4-people-in-h...
# 309     http://www.gazettes.com/news/updated-one-dead-...
# 310     http://www.chicagotribune.com/news/local/break...
# 311     http://heavy.com/news/2016/04/natalie-altier-j...
# 312     http://www.al.com/news/birmingham/index.ssf/20...
# 313     http://baltimore.cbslocal.com/2016/04/22/man-a...
# 314         http://bnonews.com/news/index.php/news/id4209
# 315     http://www.wusa9.com/news/local/1-dead-in-fore...
# 316     http://www.stltoday.com/news/local/crime-and-c...
#
#                                             Data Source 2  \
# CaseID
# 1            Lexington Examiner (KY) - September 23, 2012
# 2                  Section: Lexington True Crime Examiner
# 3       http://theadvocate.com/home/4828836-125/rampag...
# 4       http://news.google.com/newspapers?nid=1144&dat...
# 5       School Shootings: a History Part One of a seri...
# 6       http://books.google.com/books?id=EPwmTueA1m0C&...
# 7       http://www.ocregister.com/articles/allaway-257...
# 8       http://www.newsnet5.com/dpp/news/local_news/i-...
# 9       https://news.google.com/newspapers?nid=1310&da...
# 10      http://news.google.com/newspapers?id=QBtKAAAAI...
# 11      http://news.google.com/newspapers?id=uuYLAAAAI...
# 12      http://www.komonews.com/news/archive/4196186.html
# 13      http://www.reocities.com/HotSprings/5782/inmem...
# 14      http://books.google.com/books?id=YbQDAAAAMBAJ&...
# 15      http://www.nytimes.com/1984/06/30/us/6-die-in-...
# 16         http://www.utsandiego.com/san-ysidro-massacre/
# 17      http://news.google.com/newspapers?nid=1356&dat...
# 18      http://www.apnewsarchive.com/1985/Postal-Clerk...
# 19      http://news.google.com/newspapers?nid=1917&dat...
# 20      http://newsok.com/sherrill-feared-mental-illne...
# 21      http://missoulian.com/article_6535a4ff-a5c6-52...
# 22      Supreme Court of Florida Document <http://www....
# 23      http://news.google.com/newspapers?nid=1755&dat...
# 24      http://books.google.com/books?id=JiQUkwBnzgYC&...
# 25      http://chicago.cbslocal.com/2012/12/14/sandy-h...
# 26      http://www.apnewsarchive.com/1988/Chicago-Poli...
# 27      http://www.nytimes.com/1988/09/30/us/second-vi...
# 28      http://www.reocities.com/HotSprings/5782/inmem...
# 29      http://www.time.com/time/magazine/article/0,91...
# 30      http://articles.latimes.com/1989-08-11/news/mn...
# ...                                                   ...
# 287     http://www.mlive.com/news/detroit/index.ssf/20...
# 288     http://www.crimevoice.com/2016/04/08/suspect-a...
# 289     http://ksn.com/2016/03/07/wichita-pd-chief-cra...
# 290     http://www.myfoxboston.com/news/chelsea-shooti...
# 291       http://www.fox5atlanta.com/news/101462730-story
# 292     http://www.katc.com/story/31406629/police-at-l...
# 293     http://www.kmbc.com/news/police-searching-for-...
# 294     http://www.wpxi.com/news/one-of-4-questioned-i...
# 295     http://www.fox29.com/news/local-news/104653582...
# 296     http://www.fox2detroit.com/news/local-news/105...
# 297     http://www.wyff4.com/news/quadruple-shooting-l...
# 298     http://www.news-press.com/story/news/crime/201...
# 299     http://www.wsbtv.com/news/local/atlanta/police...
# 300     http://www.thewetumpkaherald.com/2016/03/21/cc...
# 301     http://www.local10.com/news/1-dead-4-injured-a...
# 302     http://www.whas11.com/news/local/brother-of-ma...
# 303     http://heralddemocrat.com/news/local/spd-says-...
# 304     http://whnt.com/2016/03/25/double-shooting-rep...
# 305     http://krqe.com/2016/04/01/police-identify-men...
# 306     http://wgntv.com/2016/04/07/5-shot-while-exiti...
# 307     http://krqe.com/2016/04/09/police-respond-to-s...
# 308     http://www.wmcactionnews5.com/story/31684724/f...
# 309     http://www.nbclosangeles.com/news/local/long-b...
# 310                                                   NaN
# 311     http://scallywagandvagabond.com/2016/04/why-je...
# 312     http://www.ctpost.com/news/crime/article/Polic...
# 313     http://www.wbaltv.com/news/4-people-including-...
# 314     http://www.wrdw.com/home/headlines/BREAKING-Co...
# 315     http://www.nbcwashington.com/news/local/1-Woma...
# 316     http://www.kmov.com/story/31854099/9-year-old-...
#
#                                             Data Source 3  \
# CaseID
# 1       http://news.google.com/newspapers?id=lkk0AAAAI...
# 2       http://www.nydailynews.com/news/crime/beauty-s...
# 3       http://www.trutv.com/library/crime/notorious_m...
# 4       http://www.leagle.com/xmlResult.aspx?page=1&xm...
# 5          http://www.newswithviews.com/Erica/Carle10.htm
# 6            http://www.newspapers.com/newspage/15323499/
# 7       http://www.dailytitan.com/2011/11/csuf-massacr...
# 8       http://www.examiner.com/article/the-san-diego-...
# 9       http://news.google.com/newspapers?nid=1891&dat...
# 10      http://www.leagle.com/xmlResult.aspx?page=1&xm...
# 11      http://www.motherjones.com/politics/2012/12/ma...
# 12      http://seattletimes.com/html/localnews/2010428...
# 13      http://sc.findacase.com/research/wfrmDocViewer...
# 14      http://articles.latimes.com/1985-02-24/news/mn...
# 15      http://www.mail-archive.com/deathpenalty@lists...
# 16      http://en.wikipedia.org/wiki/San_Ysidro_McDona...
# 17      http://news.google.com/newspapers?nid=1499&dat...
# 18      http://www.leagle.com/decision/198891983BR836_...
# 19      http://www.apnewsarchive.com/1986/Five-Shot-On...
# 20      http://enidnews.com/opinion/x518655735/Aug-20-...
# 21      http://www.apnewsarchive.com/1986/Student-Want...
# 22      http://articles.orlandosentinel.com/keyword/wi...
# 23      http://www.tampabay.com/news/publicsafety/man-...
# 24      http://murderpedia.org/male.F/f/farley-richard...
# 25      http://www.nbcchicago.com/news/local/Rememberi...
# 26      http://news.google.com/newspapers?nid=2457&dat...
# 27      http://www.charlestoncitypaper.com/charleston/...
# 28      http://books.google.com/books?id=YaLo1jgAorMC&...
# 29      http://news.google.com/newspapers?id=xpAOAAAAI...
# 30      http://www.reocities.com/HotSprings/5782/inmem...
# ...                                                   ...
# 287     http://www.fox2detroit.com/news/local-news/997...
# 288     http://www.pe.com/articles/news-798958-release...
# 289     http://www.kansas.com/news/local/crime/article...
# 290     http://www.masslive.com/news/boston/index.ssf/...
# 291     http://www.ajc.com/news/news/crime-law/cops-4-...
# 292     http://www.theadvertiser.com/videos/news/crime...
# 293     http://fox4kc.com/2016/03/08/manhunt-underway-...
# 294     http://pittsburgh.cbslocal.com/2016/03/09/mult...
# 295     http://6abc.com/news/4-people-left-wounded-aft...
# 296     http://www.fox2detroit.com/news/local-news/105...
# 297     http://www.wsbtv.com/news/local/child-man-kill...
# 298     http://www.nbc-2.com/story/31458760/shooting-r...
# 299       http://www.fox5atlanta.com/news/107791772-story
# 300     http://www.wtvm.com/story/31518283/police-4-sh...
# 301     http://miami.cbslocal.com/2016/03/20/police-in...
# 302     http://www.courier-journal.com/story/news/loca...
# 303     http://www.wfaa.com/news/crime/police-in-sherm...
# 304     http://www.timesdaily.com/news/brothers-improv...
# 305     http://www.abqjournal.com/751170/news/police-u...
# 306     http://www.nbcchicago.com/news/local/5-People-...
# 307     http://www.kob.com/albuquerque-news/4-injured-...
# 308     http://www.localmemphis.com/news/local-news/4-...
# 309     http://lbpost.com/news/crime/2000008630-one-de...
# 310     http://abc7chicago.com/news/5-shot-1-fatally-w...
# 311     http://www.khou.com/news/2-adults-2-children-f...
# 312     http://www.al.com/news/huntsville/index.ssf/20...
# 313     http://www.baltimoresun.com/news/maryland/crim...
# 314     https://www.google.com/?ion=1&espv=2#q=Wayne+H...
# 315     http://wtop.com/prince-georges-county/2016/04/...
# 316     http://www.ksdk.com/news/two-9-year-old-girls-...
#
#                                             Data Source 4  \
# CaseID
# 1       http://news.google.com/newspapers?id=PPUjAAAAI...
# 2       http://books.google.com/books?id=Cre7qsswRiwC&...
# 3       http://books.google.com/books?id=TfEDmROcZwEC&...
# 4                                                     NaN
# 5       http://books.google.com/books?id=ZuKoSskEWyIC&...
# 6                                                     NaN
# 7       http://criminalminds.wikia.com/wiki/Edward_All...
# 8       http://signofthetimes.yuku.com/topic/1258#.Uvb...
# 9       http://news.google.com/newspapers?nid=1338&dat...
# 10      http://news.google.com/newspapers?nid=1345&dat...
# 11      http://www.nytimes.com/1982/08/24/us/no-charge...
# 12                      http://wahmee.com/wahmeebook.html
# 13      http://news.google.com/newspapers?nid=861&dat=...
# 14      http://www.ourweekly.com/issues-archive/tracki...
# 15             http://www.garylavergne.com/WTDexcerpt.htm
# 16      http://www.history.com/this-day-in-history/twe...
# 17      http://news.google.com/newspapers?nid=1906&dat...
# 18      http://books.google.com/books?id=aiQ09D7nWxYC&...
# 19      http://articles.philly.com/1986-08-14/news/260...
# 20          http://en.wikipedia.org/wiki/Patrick_Sherrill
# 21      http://billingsgazette.com/news/state-and-regi...
# 22      http://www.nytimes.com/1987/04/25/us/florida-g...
# 23      http://www.apnewsarchive.com/1988/Teen-Accused...
# 24      http://articles.latimes.com/1988-02-18/news/mn...
# 25      http://abclocal.go.com/wls/story?section=news/...
# 26      http://news.google.com/newspapers?nid=1665&dat...
# 27      http://news.google.com/newspapers?nid=1665&dat...
# 28      http://www.ca5.uscourts.gov/opinions/unpub/93/...
# 29      http://www.nytimes.com/1989/01/18/us/five-chil...
# 30      http://murderpedia.org/male.T/t/taylor-john-me...
# ...                                                   ...
# 287                                                   NaN
# 288                                                   NaN
# 289                                                   NaN
# 290     http://www.necn.com/news/new-england/Seven-Sho...
# 291     http://www.myajc.com/news/news/crime-law/gwinn...
# 292                                                   NaN
# 293     http://fox40.com/2016/03/09/suspect-in-5-killi...
# 294     http://www.nbcnews.com/news/us-news/five-dead-...
# 295                                                   NaN
# 296     http://www.mlive.com/news/detroit/index.ssf/20...
# 297     http://www.ajc.com/news/news/local/child-man-k...
# 298                                                   NaN
# 299     http://www.wtoc.com/story/31488513/club-crucia...
# 300     http://www.al.com/news/montgomery/index.ssf/20...
# 301     http://newsinblack.com/one-killed-four-wounded...
# 302     http://www.dailymail.co.uk/news/article-350353...
# 303     http://www.celebritiesdeaths.com/2016/03/obitu...
# 304     http://www.al.com/news/huntsville/index.ssf/20...
# 305     http://www.kob.com/albuquerque-news/police-ide...
# 306     https://www.dnainfo.com/chicago/20160407/south...
# 307                                                   NaN
# 308                                                   NaN
# 309     http://abc7.com/news/father-shot-to-death-in-l...
# 310     http://wgntv.com/2016/04/19/five-shot-one-kill...
# 311     http://www.chron.com/neighborhood/fortbend/new...
# 312     http://www.wbrc.com/story/31776809/father-of-m...
# 313                                                   NaN
# 314     http://www.cbsnews.com/news/georgia-shooting-s...
# 315                                                   NaN
# 316                                                   NaN
#
#                                             Data Source 5  \
# CaseID
# 1       http://books.google.com/books?id=ClYEAAAAMBAJ&...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5       "Olean High School Shooting". Larrie Benton Za...
# 6                                                     NaN
# 7       http://www.dailytitan.com/2011/11/csuf-massacr...
# 8       https://www.mail-archive.com/seeknfind@ashlist...
# 9                                                     NaN
# 10      http://www.lasvegassun.com/news/1999/apr/23/sl...
# 11      http://www.nytimes.com/1982/10/14/us/florida-c...
# 12      http://murderpedia.org/male.N/images/ng_benjam...
# 13                           http://www.21cpw.com/BGP.pdf
# 14      http://www.apnewsarchive.com/1985/New-Proposal...
# 15      http://books.google.com/books?id=Hr3OBwP-lbUC&...
# 16      http://www.sandiegouniontribune.com/san-ysidro...
# 17      http://ks.findacase.com/research/wfrmDocViewer...
# 18      http://news.google.com/newspapers?nid=1964&dat...
# 19      http://joycedavid.com/wp-content/uploads/2013/...
# 20                       http://www.fdungan.com/usps2.htm
# 21      http://caselaw.findlaw.com/mt-supreme-court/11...
# 22      http://articles.latimes.com/1987-04-25/news/mn...
# 23      http://www.wtsp.com/rss/article/217730/13/Surv...
# 24      http://www.motherjones.com/politics/2012/12/ma...
# 25                                                    NaN
# 26      http://www.nytimes.com/1988/09/23/us/chicago-m...
# 27      http://law.justia.com/cases/federal/appellate-...
# 28      http://www.thehospitalsecurityreporter.com/pdf...
# 29                                                    NaN
# 30                                                    NaN
# ...                                                   ...
# 287                                                   NaN
# 288                                                   NaN
# 289                                                   NaN
# 290     http://www.necn.com/news/new-england/Teen-Char...
# 291                                                   NaN
# 292                                                   NaN
# 293     http://www.kansascity.com/news/local/crime/art...
# 294     http://abcnews.go.com/US/dead-injured-backyard...
# 295                                                   NaN
# 296     http://www.mlive.com/news/detroit/index.ssf/20...
# 297                                                   NaN
# 298                                                   NaN
# 299                                                   NaN
# 300                                                   NaN
# 301                                                   NaN
# 302                                                   NaN
# 303                                                   NaN
# 304                                                   NaN
# 305                                                   NaN
# 306                                                   NaN
# 307                                                   NaN
# 308                                                   NaN
# 309                                                   NaN
# 310     https://www.dnainfo.com/chicago/20160419/aubur...
# 311     http://news4sanantonio.com/news/local/4-dead-i...
# 312                                                   NaN
# 313                                                   NaN
# 314     http://www.wrdw.com/home/headlines/911-calls-r...
# 315                                                   NaN
# 316                                                   NaN
#
#                                             Data Source 6  \
# CaseID
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18      http://books.google.com/books?id=3B4lTTZE58oC&...
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22      http://www.motherjones.com/politics/2012/12/ma...
# 23                                                    NaN
# 24      http://news.google.com/newspapers?id=FmYzAAAAI...
# 25                                                    NaN
# 26                                                    NaN
# 27      https://law.resource.org/pub/us/case/reporter/...
# 28                                                    NaN
# 29                                                    NaN
# 30                                                    NaN
# ...                                                   ...
# 287                                                   NaN
# 288                                                   NaN
# 289                                                   NaN
# 290                                                   NaN
# 291                                                   NaN
# 292                                                   NaN
# 293     http://www.kansascity.com/news/local/crime/art...
# 294                                                   NaN
# 295                                                   NaN
# 296                                                   NaN
# 297                                                   NaN
# 298                                                   NaN
# 299                                                   NaN
# 300                                                   NaN
# 301                                                   NaN
# 302                                                   NaN
# 303                                                   NaN
# 304                                                   NaN
# 305                                                   NaN
# 306                                                   NaN
# 307                                                   NaN
# 308                                                   NaN
# 309                                                   NaN
# 310     http://www.nbcchicago.com/news/local/1-Killed-...
# 311                                                   NaN
# 312                                                   NaN
# 313                                                   NaN
# 314     http://www.huffingtonpost.com/entry/georgia-sh...
# 315                                                   NaN
# 316                                                   NaN
#
#                                             Data Source 7 Military Experience  \
# CaseID
# 1                                                     NaN                 Yes
# 2                                                     NaN             Unknown
# 3                                                     NaN             Unknown
# 4                                                     NaN             Unknown
# 5                                                     NaN             Unknown
# 6                                                     NaN             Unknown
# 7                                                     NaN             Unknown
# 8                                                     NaN             Unknown
# 9                                                     NaN             Unknown
# 10                                                    NaN             Unknown
# 11                                                    NaN             Unknown
# 12                                                    NaN             Unknown
# 13                                                    NaN             Unknown
# 14                                                    NaN             Unknown
# 15                                                    NaN             Unknown
# 16                                                    NaN             Unknown
# 17                                                    NaN             Unknown
# 18      http://psychwatch.blogspot.com/2007/04/link-be...             Unknown
# 19                                                    NaN             Unknown
# 20                                                    NaN             Unknown
# 21                                                    NaN             Unknown
# 22                                                    NaN             Unknown
# 23                                                    NaN             Unknown
# 24      http://news.google.com/newspapers?id=uqxAAAAAI...             Unknown
# 25                                                    NaN             Unknown
# 26                                                    NaN                 Yes
# 27      http://books.google.com/books?id=loDr8rpeCeoC&...             Unknown
# 28                                                    NaN             Unknown
# 29                                                    NaN             Unknown
# 30                                                    NaN                 Yes
# ...                                                   ...                 ...
# 287     http://www.gunviolencearchive.org/incident/513549             Unknown
# 288     http://www.gunviolencearchive.org/incident/513640             Unknown
# 289     http://www.gunviolencearchive.org/incident/516758             Unknown
# 290     http://www.gunviolencearchive.org/incident/517058             Unknown
# 291     http://www.gunviolencearchive.org/incident/517114                 NaN
# 292     http://www.gunviolencearchive.org/incident/517895             Unknown
# 293     http://www.gunviolencearchive.org/incident/518436             Unknown
# 294     http://www.gunviolencearchive.org/incident/519541             Unknown
# 295     http://www.gunviolencearchive.org/incident/520290             Unknown
# 296     http://www.gunviolencearchive.org/incident/520767             Unknown
# 297                                                   NaN                 NaN
# 298     http://www.gunviolencearchive.org/incident/522122             Unknown
# 299     http://www.gunviolencearchive.org/incident/523044             Unknown
# 300                                                   NaN                 NaN
# 301                                                   NaN             Unknown
# 302                                                   NaN                 Yes
# 303                                                   NaN                 NaN
# 304                                                   NaN             Unknown
# 305                                                   NaN             Unknown
# 306     http://www.gunviolencearchive.org/incident/535927             Unknown
# 307     http://www.gunviolencearchive.org/incident/537085             Unknown
# 308     http://www.gunviolencearchive.org/incident/537311             Unknown
# 309     http://www.gunviolencearchive.org/incident/543244             Unknown
# 310     http://www.gunviolencearchive.org/incident/543132             Unknown
# 311                                                   NaN             Unknown
# 312                                                   NaN             Unknown
# 313                                                   NaN             Unknown
# 314                                                   NaN                 NaN
# 315                                                   NaN             Unknown
# 316     http://www.gunviolencearchive.org/incident/550445             Unknown
#
#        Class
# CaseID
# 1        SPK
# 2         MS
# 3        SPK
# 4         MS
# 5         MS
# 6         MS
# 7         MS
# 8         MS
# 9         MS
# 10        MS
# 11        MS
# 12        MS
# 13        MS
# 14        MS
# 15        MS
# 16        MS
# 17        MS
# 18        MS
# 19        MS
# 20        MS
# 21        MS
# 22       SPK
# 23        MS
# 24        MS
# 25        MS
# 26       SPK
# 27        MS
# 28        MS
# 29        MS
# 30        MS
# ...      ...
# 287       MS
# 288       MS
# 289       MS
# 290       MS
# 291       MS
# 292       MS
# 293       MS
# 294       MS
# 295       MS
# 296       MS
# 297      FMS
# 298       MS
# 299       MS
# 300       MS
# 301       MS
# 302      FMS
# 303      FMS
# 304      FMS
# 305      FMS
# 306       MS
# 307       MS
# 308       MS
# 309       MS
# 310       MS
# 311      FMS
# 312       MS
# 313       MS
# 314       MS
# 315       MS
# 316       MS
#
# [307 rows x 47 columns]

# %%
with open('store/MSA/Stanford_MSA_Database_for_release.csv',
          encoding='utf-8',
          newline='') as csv_file:
    msa_reader = DictReader(csv_file,
                            delimiter="\t",
                            dialect='excel',
                            quotechar='"',
                            skipinitialspace=True)
    
    fieldnames = msa_reader.fieldnames
    if fieldnames == str(fieldnames).find(" "):
        fieldnames = [name.replace(name, '"' + name + '"') for name in fieldnames]
    print("MSA Reader: \n", fieldnames, "\n")
    
    table_name = 'Shootings'
    counter = 0

    drop_sql = f"DROP TABLE IF EXISTS {table_name};"
    c.execute(drop_sql)
    print("Drop SQL: \n", drop_sql, "\n")

    create_sql_table = f"CREATE TABLE {table_name} ({', '.join([ f'{column.strip()}' for column in fieldnames])})"
    print("Create SQL Table: \n", create_sql_table, "\n")

    insert_sql = f"INSERT INTO {table_name} VALUES ({', '.join([ '?' for column in row ])})"
        for row in msa_reader:
            try:
                counter += 1
                print("Record #", counter, ":\n", row, "\n")

            except Error as error:
                exit(f'file {csv_file},'
                    f'line {msa_reader.line_num}: {error}')
                print(error)

conn.commit()
c.close()
# Out:
#   File "<ipython-input-11-3edf102b70ce>", line 26
#     for row in msa_reader:
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# While every Congress is unique, within the follwing file is the makeup of the 2015 - 2016 U.S. Congress as reported by *The Washington Post*.

# %%
# File for Web Scrapping & Parsing

gun_legislation_url = 'https://www.washingtonpost.com/graphics/national/gun-legislation/'
gun_legislation_html_soup = BeautifulSoup(urlopen(gun_legislation_url), 'html.parser')
stats_json_string = gun_legislation_html_soup.find('script', attrs={'src': 'js/base.js?c=a90e33a675e9d0ac31328c0ce0d2e12b16035540'})
print(stats_json_string)
# Out:
# <script charset="utf-8" src="js/base.js?c=a90e33a675e9d0ac31328c0ce0d2e12b16035540" type="text/javascript"></script>

# %% [markdown]
# Having discovered where the data lives, we then must convert the JavaScript file ready for parsing.  In this case we cut off the top and bottom code sections, then replace the unquoted keywords to being double-quoted per the JSON library's requirement for parsing.

# %%
full_gun_legislation_url = 'https://www.washingtonpost.com/graphics/national/gun-legislation/js/base.js?c=a90e33a675e9d0ac31328c0ce0d2e12b16035540'
legislation_request = requests.get(full_gun_legislation_url)

try:
    # print("Headers: \n", legislation_request.headers, "\n")
    b = legislation_request.text.find("{first:")
    e = legislation_request.text.find(":6}]")
    scrape = legislation_request.text[b - 1:e + 4]

    scrape = scrape.replace('first:', '"first":')
    scrape = scrape.replace('last:', '"last":')
    scrape = scrape.replace('fullLast:', '"fullLast":')
    scrape = scrape.replace('party:', '"party":')
    scrape = scrape.replace('house:', '"house":')
    scrape = scrape.replace('state:', '"state":')
    scrape = scrape.replace('control:', '"control":')
    scrape = scrape.replace('rights:', '"rights":')
    scrape = scrape.replace('id:', '"id":')
    scrape = scrape.replace('score:', '"score":')
    scrape = scrape.replace('pi:', '"pi":')
    scrape = scrape.replace('grade:', '"grade":')
    scrape = scrape.replace('gi:', '"gi":')

    json_scrape = loads(scrape)
    # print("Scrape: \n", json_scrape, "\n")

except Error as error:
    print("Error Status Code: \n", legislation_request.status_code)

# %%
# Headers

first = json_scrape[0]["first"]
last = json_scrape[0]["last"]
fullLast = json_scrape[0]["fullLast"]
party = json_scrape[0]["party"]
house = json_scrape[0]["house"]
state = json_scrape[0]["state"]
control = json_scrape[0]["control"]
rights = json_scrape[0]["rights"]
id = json_scrape[0]["id"]
score = json_scrape[0]["score"]
pi = json_scrape[0]["pi"]
grade = json_scrape[0]["grade"]
gi = json_scrape[0]["gi"]

data = [first, last, fullLast, party, house, state, control, rights, id, score, pi, grade, gi]
table_name = "Legislation"
counter = 0

c = conn.cursor()

c.execute('DROP TABLE IF EXISTS table_name')
c.execute('CREATE TABLE IF NOT EXISTS table_name'
          '('
          'first,'
          'last,'
          'fullLast,'
          'party,'
          'house,'
          'state,'
          'control,'
          'rights,'
          'id,'
          'score,'
          'pi,'
          'grade,'
          'gi'
          ')')

for row in json_scrape:
    insertsql = f"INSERT INTO {table_name} VALUES ({', '.join([ '?' for column in row ])})"
    counter += 1
    print("Record #", counter, ":\n", row, "\n")

# Close the SQL connection to our SQLite database
conn.commit()
c.close()
# Out:
# Record # 1 :
#  {'first': 'Ralph', 'last': 'Abraham', 'fullLast': 'Abraham', 'party': 'r', 'house': 'h', 'state': 'LA', 'control': [], 'rights': [59, 62, 64, 70, 74, 75, 90, 94, 84], 'id': 0, 'score': 9, 'pi': 1, 'grade': 'AQ', 'gi': 13}
#
# Record # 2 :
#  {'first': 'Alma', 'last': 'Adams', 'fullLast': 'Adams', 'party': 'd', 'house': 'h', 'state': 'NC', 'control': [2, 9, 10, 14, 15, 17, 31, 37, 40, 50, 53], 'rights': [], 'id': 1, 'score': -11, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 3 :
#  {'first': 'Robert', 'last': 'Aderholt', 'fullLast': 'Aderholt', 'party': 'r', 'house': 'h', 'state': 'AL', 'control': [], 'rights': [64, 71, 78, 90, 94], 'id': 2, 'score': 5, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 4 :
#  {'first': 'Pete', 'last': 'Aguilar', 'fullLast': 'Aguilar', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [9, 10, 14, 50, 53], 'rights': [], 'id': 3, 'score': -5, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 5 :
#  {'first': 'Rick', 'last': 'Allen', 'fullLast': 'Allen', 'party': 'r', 'house': 'h', 'state': 'GA', 'control': [], 'rights': [55, 57, 59, 62, 63, 64, 65, 71, 74, 78, 84, 90, 95], 'id': 4, 'score': 13, 'pi': 0, 'grade': 'A', 'gi': 0}
#
# Record # 6 :
#  {'first': 'Mark', 'last': 'Amodei', 'fullLast': 'Amodei', 'party': 'r', 'house': 'h', 'state': 'NV', 'control': [], 'rights': [57, 59, 62, 71, 74, 90], 'id': 5, 'score': 6, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 7 :
#  {'first': 'Brad', 'last': 'Ashford', 'fullLast': 'Ashford', 'party': 'd', 'house': 'h', 'state': 'NE', 'control': [9], 'rights': [], 'id': 6, 'score': -1, 'pi': 1, 'grade': 'C', 'gi': 0}
#
# Record # 8 :
#  {'first': 'Brian', 'last': 'Babin', 'fullLast': 'Babin', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [55, 56, 57, 59, 62, 63, 64, 65, 71, 74, 75, 80, 84, 87, 90, 94, 95, 97], 'id': 7, 'score': 18, 'pi': 0, 'grade': 'AQ', 'gi': 1}
#
# Record # 9 :
#  {'first': 'Tammy', 'last': 'Baldwin', 'fullLast': 'Baldwin', 'party': 'd', 'house': 's', 'state': 'WI', 'control': [11, 34], 'rights': [86], 'id': 8, 'score': 0, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 10 :
#  {'first': 'Lou', 'last': 'Barletta', 'fullLast': 'Barletta', 'party': 'r', 'house': 'h', 'state': 'PA', 'control': [], 'rights': [57, 62, 74, 90], 'id': 9, 'score': 4, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 11 :
#  {'first': 'Garland', 'last': 'Barr', 'fullLast': 'Barr', 'party': 'r', 'house': 'h', 'state': 'KY', 'control': [], 'rights': [55, 57, 59, 62, 69, 74, 78, 84, 90, 94], 'id': 10, 'score': 10, 'pi': 0, 'grade': 'A', 'gi': 0}
#
# Record # 12 :
#  {'first': 'John', 'last': 'Barrasso', 'fullLast': 'Barrasso', 'party': 'r', 'house': 's', 'state': 'WY', 'control': [], 'rights': [61], 'id': 11, 'score': 1, 'pi': 1, 'grade': 'A', 'gi': 0}
#
# Record # 13 :
#  {'first': 'Joe', 'last': 'Barton', 'fullLast': 'Barton', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [62, 77, 90, 94, 97], 'id': 12, 'score': 5, 'pi': 14, 'grade': 'A', 'gi': 14}
#
# Record # 14 :
#  {'first': 'Karen', 'last': 'Bass', 'fullLast': 'Bass', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [1, 4, 10, 14, 26, 50, 53], 'rights': [], 'id': 13, 'score': -7, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 15 :
#  {'first': 'Joyce', 'last': 'Beatty', 'fullLast': 'Beatty', 'party': 'd', 'house': 'h', 'state': 'OH', 'control': [10, 31], 'rights': [], 'id': 14, 'score': -2, 'pi': 8, 'grade': 'F', 'gi': 18}
#
# Record # 16 :
#  {'first': 'Xavier', 'last': 'Becerra', 'fullLast': 'Becerra', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [10, 50], 'rights': [], 'id': 15, 'score': -2, 'pi': 11, 'grade': 'F', 'gi': 11}
#
# Record # 17 :
#  {'first': 'Dan', 'last': 'Benishek', 'fullLast': 'Benishek', 'party': 'r', 'house': 'h', 'state': 'MI', 'control': [], 'rights': [57, 59, 62, 64, 84, 90, 93, 94], 'id': 16, 'score': 8, 'pi': 1, 'grade': 'A+', 'gi': 12}
#
# Record # 18 :
#  {'first': 'Ami', 'last': 'Bera', 'fullLast': 'Bera', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [9, 10, 14], 'rights': [], 'id': 17, 'score': -3, 'pi': 1, 'grade': 'F', 'gi': 14}
#
# Record # 19 :
#  {'first': 'Donald', 'last': 'Beyer', 'fullLast': 'Beyer', 'party': 'd', 'house': 'h', 'state': 'VA', 'control': [2, 7, 9, 10, 12, 14, 15, 29, 31, 35, 37, 50, 53, 25], 'rights': [], 'id': 18, 'score': -14, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 20 :
#  {'first': 'Gus', 'last': 'Bilirakis', 'fullLast': 'Bilirakis', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [62, 75, 78], 'id': 19, 'score': 3, 'pi': 1, 'grade': 'A', 'gi': 0}
#
# Record # 21 :
#  {'first': 'Sanford', 'last': 'Bishop', 'fullLast': 'Bishop', 'party': 'd', 'house': 'h', 'state': 'GA', 'control': [], 'rights': [62], 'id': 20, 'score': 1, 'pi': 22, 'grade': 'A', 'gi': 1}
#
# Record # 22 :
#  {'first': 'Mike', 'last': 'Bishop', 'fullLast': 'Bishop', 'party': 'r', 'house': 'h', 'state': 'MI', 'control': [], 'rights': [55, 62], 'id': 21, 'score': 2, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 23 :
#  {'first': 'Rob', 'last': 'Bishop', 'fullLast': 'Bishop', 'party': 'r', 'house': 'h', 'state': 'UT', 'control': [], 'rights': [55, 56, 57, 62, 64, 90, 74], 'id': 22, 'score': 7, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 24 :
#  {'first': 'Diane', 'last': 'Black', 'fullLast': 'Black', 'party': 'r', 'house': 'h', 'state': 'TN', 'control': [], 'rights': [57, 59, 62, 63, 74, 75, 90], 'id': 23, 'score': 7, 'pi': 12, 'grade': 'A', 'gi': 12}
#
# Record # 25 :
#  {'first': 'Marsha', 'last': 'Blackburn', 'fullLast': 'Blackburn', 'party': 'r', 'house': 'h', 'state': 'TN', 'control': [], 'rights': [59, 62, 64, 74, 75, 90, 94], 'id': 24, 'score': 7, 'pi': 2, 'grade': 'A', 'gi': 2}
#
# Record # 26 :
#  {'first': 'Rod', 'last': 'Blum', 'fullLast': 'Blum', 'party': 'r', 'house': 'h', 'state': 'IA', 'control': [], 'rights': [55, 62, 90], 'id': 25, 'score': 3, 'pi': 10, 'grade': 'AQ', 'gi': 17}
#
# Record # 27 :
#  {'first': 'Earl', 'last': 'Blumenauer', 'fullLast': 'Blumenauer', 'party': 'd', 'house': 'h', 'state': 'OR', 'control': [2, 7, 9, 10, 13, 14, 15, 17, 19, 20, 24, 25, 26, 27, 29, 31, 36, 37, 50, 51], 'rights': [], 'id': 26, 'score': -20, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 28 :
#  {'first': 'Richard', 'last': 'Blumenthal', 'fullLast': 'Blumenthal', 'party': 'd', 'house': 's', 'state': 'CT', 'control': [8, 11, 30, 38, 28, 34, 42, 44], 'rights': [], 'id': 27, 'score': -8, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 29 :
#  {'first': 'Roy', 'last': 'Blunt', 'fullLast': 'Blunt', 'party': 'r', 'house': 's', 'state': 'MO', 'control': [], 'rights': [61, 92], 'id': 28, 'score': 2, 'pi': 1, 'grade': 'A', 'gi': 0}
#
# Record # 30 :
#  {'first': 'Suzanne', 'last': 'Bonamici', 'fullLast': 'Bonamici', 'party': 'd', 'house': 'h', 'state': 'OR', 'control': [2, 9, 10, 14, 15, 27, 29, 31, 50], 'rights': [], 'id': 29, 'score': -9, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 31 :
#  {'first': 'Cory', 'last': 'Booker', 'fullLast': 'Booker', 'party': 'd', 'house': 's', 'state': 'NJ', 'control': [44, 49], 'rights': [], 'id': 30, 'score': -2, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 32 :
#  {'first': 'John', 'last': 'Boozman', 'fullLast': 'Boozman', 'party': 'r', 'house': 's', 'state': 'AR', 'control': [], 'rights': [58, 61], 'id': 31, 'score': 2, 'pi': 6, 'grade': 'A', 'gi': 4}
#
# Record # 33 :
#  {'first': 'Madeleine', 'last': 'Bordallo', 'fullLast': 'Bordallo', 'party': 'd', 'house': 'h', 'state': 'GU', 'control': [10], 'rights': [], 'id': 32, 'score': -1, 'pi': 6, 'grade': 'Not rated', 'gi': 11}
#
# Record # 34 :
#  {'first': 'Mike', 'last': 'Bost', 'fullLast': 'Bost', 'party': 'r', 'house': 'h', 'state': 'IL', 'control': [], 'rights': [57, 59, 62, 64, 65, 78, 90, 95], 'id': 33, 'score': 8, 'pi': 11, 'grade': 'A+', 'gi': 17}
#
# Record # 35 :
#  {'first': 'Charles', 'last': 'Boustany', 'fullLast': 'Boustany', 'party': 'r', 'house': 'h', 'state': 'LA', 'control': [], 'rights': [55, 59, 62, 74, 75, 90, 94], 'id': 34, 'score': 7, 'pi': 3, 'grade': 'A', 'gi': 3}
#
# Record # 36 :
#  {'first': 'Barbara', 'last': 'Boxer', 'fullLast': 'Boxer', 'party': 'd', 'house': 's', 'state': 'CA', 'control': [8, 11, 34, 44, 38], 'rights': [], 'id': 35, 'score': -5, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 37 :
#  {'first': 'Brendan', 'last': 'Boyle', 'fullLast': 'Boyle', 'party': 'd', 'house': 'h', 'state': 'PA', 'control': [1, 9, 10, 15, 17, 19, 26, 27, 31, 37, 40, 50], 'rights': [], 'id': 36, 'score': -12, 'pi': 0, 'grade': 'D', 'gi': 0}
#
# Record # 38 :
#  {'first': 'Robert', 'last': 'Brady', 'fullLast': 'Brady', 'party': 'd', 'house': 'h', 'state': 'PA', 'control': [9, 10, 14, 50], 'rights': [], 'id': 37, 'score': -4, 'pi': 3, 'grade': 'F', 'gi': 14}
#
# Record # 39 :
#  {'first': 'Kevin', 'last': 'Brady', 'fullLast': 'Brady', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [62, 64, 74, 90, 94, 97], 'id': 38, 'score': 6, 'pi': 12, 'grade': 'A', 'gi': 12}
#
# Record # 40 :
#  {'first': 'David', 'last': 'Brat', 'fullLast': 'Brat', 'party': 'r', 'house': 'h', 'state': 'VA', 'control': [], 'rights': [62, 64, 75, 90, 94], 'id': 39, 'score': 5, 'pi': 2, 'grade': 'AQ', 'gi': 26}
#
# Record # 41 :
#  {'first': 'Jim', 'last': 'Bridenstine', 'fullLast': 'Bridenstine', 'party': 'r', 'house': 'h', 'state': 'OK', 'control': [], 'rights': [56, 57, 59, 62, 64, 65, 84, 90, 93, 94], 'id': 40, 'score': 10, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 42 :
#  {'first': 'Susan', 'last': 'Brooks', 'fullLast': 'Brooks', 'party': 'r', 'house': 'h', 'state': 'IN', 'control': [], 'rights': [57, 62], 'id': 41, 'score': 2, 'pi': 11, 'grade': 'A', 'gi': 11}
#
# Record # 43 :
#  {'first': 'Mo', 'last': 'Brooks', 'fullLast': 'Brooks', 'party': 'r', 'house': 'h', 'state': 'AL', 'control': [], 'rights': [55, 62, 63, 64, 74, 75, 84, 90, 93, 94, 95], 'id': 42, 'score': 11, 'pi': 0, 'grade': 'A', 'gi': 0}
#
# Record # 44 :
#  {'first': 'Corrine', 'last': 'Brown', 'fullLast': 'Brown', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [9, 10, 14, 50, 54], 'rights': [], 'id': 43, 'score': -5, 'pi': 5, 'grade': 'F', 'gi': 5}
#
# Record # 45 :
#  {'first': 'Sherrod', 'last': 'Brown', 'fullLast': 'Brown', 'party': 'd', 'house': 's', 'state': 'OH', 'control': [11], 'rights': [], 'id': 44, 'score': -1, 'pi': 1, 'grade': 'F', 'gi': 4}
#
# Record # 46 :
#  {'first': 'Julia', 'last': 'Brownley', 'fullLast': 'Brownley', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [9, 10, 14, 15, 27, 31, 37, 50], 'rights': [], 'id': 45, 'score': -8, 'pi': 0, 'grade': 'F', 'gi': 1}
#
# Record # 47 :
#  {'first': 'Vern', 'last': 'Buchanan', 'fullLast': 'Buchanan', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [57, 75], 'id': 46, 'score': 2, 'pi': 2, 'grade': 'A', 'gi': 2}
#
# Record # 48 :
#  {'first': 'Ken', 'last': 'Buck', 'fullLast': 'Buck', 'party': 'r', 'house': 'h', 'state': 'CO', 'control': [], 'rights': [59, 63, 64, 74, 95], 'id': 47, 'score': 5, 'pi': 3, 'grade': 'A', 'gi': 3}
#
# Record # 49 :
#  {'first': 'Larry', 'last': 'Bucshon', 'fullLast': 'Bucshon', 'party': 'r', 'house': 'h', 'state': 'IN', 'control': [], 'rights': [57, 59, 62, 63, 64, 94], 'id': 48, 'score': 6, 'pi': 2, 'grade': 'A', 'gi': 2}
#
# Record # 50 :
#  {'first': 'Michael', 'last': 'Burgess', 'fullLast': 'Burgess', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [55, 62, 63, 67, 90, 94, 95], 'id': 49, 'score': 7, 'pi': 4, 'grade': 'A', 'gi': 4}
#
# Record # 51 :
#  {'first': 'Richard', 'last': 'Burr', 'fullLast': 'Burr', 'party': 'r', 'house': 's', 'state': 'NC', 'control': [], 'rights': [61], 'id': 50, 'score': 1, 'pi': 9, 'grade': 'A+', 'gi': 9}
#
# Record # 52 :
#  {'first': 'Cheri', 'last': 'Bustos', 'fullLast': 'Bustos', 'party': 'd', 'house': 'h', 'state': 'IL', 'control': [10, 15], 'rights': [], 'id': 51, 'score': -2, 'pi': 14, 'grade': 'A-', 'gi': 0}
#
# Record # 53 :
#  {'first': 'George', 'last': 'Butterfield', 'fullLast': 'Butterfield', 'party': 'd', 'house': 'h', 'state': 'NC', 'control': [10, 31, 50], 'rights': [], 'id': 52, 'score': -3, 'pi': 8, 'grade': 'D', 'gi': 5}
#
# Record # 54 :
#  {'first': 'Bradley', 'last': 'Byrne', 'fullLast': 'Byrne', 'party': 'r', 'house': 'h', 'state': 'AL', 'control': [], 'rights': [57, 62, 63, 65, 90, 94], 'id': 53, 'score': 6, 'pi': 3, 'grade': 'A', 'gi': 3}
#
# Record # 55 :
#  {'first': 'Ken', 'last': 'Calvert', 'fullLast': 'Calvert', 'party': 'r', 'house': 'h', 'state': 'CA', 'control': [], 'rights': [71], 'id': 54, 'score': 1, 'pi': 11, 'grade': 'A+', 'gi': 15}
#
# Record # 56 :
#  {'first': 'Shelley', 'last': 'Capito', 'fullLast': 'Capito', 'party': 'r', 'house': 's', 'state': 'WV', 'control': [], 'rights': [61], 'id': 55, 'score': 1, 'pi': 2, 'grade': 'A', 'gi': 1}
#
# Record # 57 :
#  {'first': 'Lois', 'last': 'Capps', 'fullLast': 'Capps', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [4, 9, 10, 12, 14, 19, 27, 29, 37, 40, 50, 7, 15], 'rights': [], 'id': 56, 'score': -13, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 58 :
#  {'first': 'Michael', 'last': 'Capuano', 'fullLast': 'Capuano', 'party': 'd', 'house': 'h', 'state': 'MA', 'control': [9, 10, 14, 15, 37, 50], 'rights': [], 'id': 57, 'score': -6, 'pi': 1, 'grade': 'F', 'gi': 4}
#
# Record # 59 :
#  {'first': 'Tony', 'last': 'Cardenas', 'fullLast': 'Cardenas', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [2, 3, 9, 10, 14, 15, 19, 36, 37, 50, 53], 'rights': [], 'id': 58, 'score': -11, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 60 :
#  {'first': 'Benjamin', 'last': 'Cardin', 'fullLast': 'Cardin', 'party': 'd', 'house': 's', 'state': 'MD', 'control': [44], 'rights': [], 'id': 59, 'score': -1, 'pi': 5, 'grade': 'F', 'gi': 5}
#
# Record # 61 :
#  {'first': 'John', 'last': 'Carney', 'fullLast': 'Carney', 'party': 'd', 'house': 'h', 'state': 'DE', 'control': [9, 10, 14, 31, 37, 50], 'rights': [], 'id': 60, 'score': -6, 'pi': 7, 'grade': 'F', 'gi': 7}
#
# Record # 62 :
#  {'first': 'Thomas', 'last': 'Carper', 'fullLast': 'Carper', 'party': 'd', 'house': 's', 'state': 'DE', 'control': [8, 11], 'rights': [], 'id': 61, 'score': -2, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 63 :
#  {'first': 'Andr&#xE9;', 'last': 'Carson', 'fullLast': 'Carson', 'party': 'd', 'house': 'h', 'state': 'IN', 'control': [1, 2, 9, 10, 31, 50], 'rights': [], 'id': 62, 'score': -6, 'pi': 2, 'grade': 'D', 'gi': 0}
#
# Record # 64 :
#  {'first': 'John', 'last': 'Carter', 'fullLast': 'Carter', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [55, 57, 62, 63, 64, 65, 66, 71, 90, 97], 'id': 63, 'score': 10, 'pi': 2, 'grade': 'A+', 'gi': 6}
#
# Record # 65 :
#  {'first': 'Buddy', 'last': 'Carter', 'fullLast': 'Carter', 'party': 'r', 'house': 'h', 'state': 'GA', 'control': [], 'rights': [62, 74, 75, 93, 94], 'id': 64, 'score': 5, 'pi': 4, 'grade': 'A', 'gi': 4}
#
# Record # 66 :
#  {'first': 'Matthew', 'last': 'Cartwright', 'fullLast': 'Cartwright', 'party': 'd', 'house': 'h', 'state': 'PA', 'control': [1, 2, 9, 10, 27, 40, 50], 'rights': [], 'id': 65, 'score': -7, 'pi': 7, 'grade': 'F', 'gi': 7}
#
# Record # 67 :
#  {'first': 'Robert', 'last': 'Casey', 'fullLast': 'Casey', 'party': 'd', 'house': 's', 'state': 'PA', 'control': [11], 'rights': [], 'id': 66, 'score': -1, 'pi': 2, 'grade': 'B+', 'gi': 0}
#
# Record # 68 :
#  {'first': 'Bill', 'last': 'Cassidy', 'fullLast': 'Cassidy', 'party': 'r', 'house': 's', 'state': 'LA', 'control': [], 'rights': [98], 'id': 67, 'score': 1, 'pi': 3, 'grade': 'Not rated', 'gi': 18}
#
# Record # 69 :
#  {'first': 'Kathy', 'last': 'Castor', 'fullLast': 'Castor', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [9, 10, 14, 17, 27, 31, 37, 50, 53], 'rights': [], 'id': 68, 'score': -9, 'pi': 6, 'grade': 'F', 'gi': 6}
#
# Record # 70 :
#  {'first': 'Joaquin', 'last': 'Castro', 'fullLast': 'Castro', 'party': 'd', 'house': 'h', 'state': 'TX', 'control': [10], 'rights': [], 'id': 69, 'score': -1, 'pi': 2, 'grade': 'D', 'gi': 4}
#
# Record # 71 :
#  {'first': 'Steve', 'last': 'Chabot', 'fullLast': 'Chabot', 'party': 'r', 'house': 'h', 'state': 'OH', 'control': [], 'rights': [57, 59, 62, 64, 65, 74, 75, 90, 94, 95], 'id': 70, 'score': 10, 'pi': 3, 'grade': 'A', 'gi': 2}
#
# Record # 72 :
#  {'first': 'Jason', 'last': 'Chaffetz', 'fullLast': 'Chaffetz', 'party': 'r', 'house': 'h', 'state': 'UT', 'control': [], 'rights': [62, 74, 75], 'id': 71, 'score': 3, 'pi': 2, 'grade': 'A', 'gi': 2}
#
# Record # 73 :
#  {'first': 'Judy', 'last': 'Chu', 'fullLast': 'Chu', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [1, 10, 14, 15, 27, 29, 37, 50, 53], 'rights': [], 'id': 72, 'score': -9, 'pi': 2, 'grade': 'F', 'gi': 2}
#
# Record # 74 :
#  {'first': 'David', 'last': 'Cicilline', 'fullLast': 'Cicilline', 'party': 'd', 'house': 'h', 'state': 'RI', 'control': [4, 6, 7, 9, 10, 13, 14, 15, 17, 19, 35, 36, 37, 26, 27, 50, 53], 'rights': [], 'id': 73, 'score': -17, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 75 :
#  {'first': 'Katherine', 'last': 'Clark', 'fullLast': 'Clark', 'party': 'd', 'house': 'h', 'state': 'MA', 'control': [2, 9, 10, 14, 15, 17, 19, 20, 21, 27, 29, 31, 37, 40, 50, 53], 'rights': [], 'id': 74, 'score': -16, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 76 :
#  {'first': 'Yvette', 'last': 'Clarke', 'fullLast': 'Clarke', 'party': 'd', 'house': 'h', 'state': 'NY', 'control': [10, 12, 14, 25, 31, 50, 51, 53], 'rights': [], 'id': 75, 'score': -8, 'pi': 1, 'grade': 'F', 'gi': 2}
#
# Record # 77 :
#  {'first': 'Curtis', 'last': 'Clawson', 'fullLast': 'Clawson', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [62], 'id': 76, 'score': 1, 'pi': 2, 'grade': 'A', 'gi': 2}
#
# Record # 78 :
#  {'first': 'Lacy', 'last': 'Clay', 'fullLast': 'Clay', 'party': 'd', 'house': 'h', 'state': 'MO', 'control': [10], 'rights': [], 'id': 77, 'score': -1, 'pi': 3, 'grade': 'F', 'gi': 6}
#
# Record # 79 :
#  {'first': 'Emanuel', 'last': 'Cleaver', 'fullLast': 'Cleaver', 'party': 'd', 'house': 'h', 'state': 'MO', 'control': [10, 31], 'rights': [], 'id': 78, 'score': -2, 'pi': 3, 'grade': 'F', 'gi': 15}
#
# Record # 80 :
#  {'first': 'James', 'last': 'Clyburn', 'fullLast': 'Clyburn', 'party': 'd', 'house': 'h', 'state': 'SC', 'control': [10, 31], 'rights': [], 'id': 79, 'score': -2, 'pi': 4, 'grade': 'F', 'gi': 8}
#
# Record # 81 :
#  {'first': 'Daniel', 'last': 'Coats', 'fullLast': 'Coats', 'party': 'r', 'house': 's', 'state': 'IN', 'control': [], 'rights': [61], 'id': 80, 'score': 1, 'pi': 4, 'grade': 'C+', 'gi': 16}
#
# Record # 82 :
#  {'first': 'Thad', 'last': 'Cochran', 'fullLast': 'Cochran', 'party': 'r', 'house': 's', 'state': 'MS', 'control': [], 'rights': [61], 'id': 81, 'score': 1, 'pi': 5, 'grade': 'A+', 'gi': 10}
#
# Record # 83 :
#  {'first': 'Mike', 'last': 'Coffman', 'fullLast': 'Coffman', 'party': 'r', 'house': 'h', 'state': 'CO', 'control': [], 'rights': [57], 'id': 82, 'score': 1, 'pi': 3, 'grade': 'A', 'gi': 3}
#
# Record # 84 :
#  {'first': 'Steve', 'last': 'Cohen', 'fullLast': 'Cohen', 'party': 'd', 'house': 'h', 'state': 'TN', 'control': [3, 9, 10, 14, 19, 24, 26, 29, 31, 37, 50, 51], 'rights': [75], 'id': 83, 'score': 0, 'pi': 3, 'grade': 'F', 'gi': 5}
#
# Record # 85 :
#  {'first': 'Tom', 'last': 'Cole', 'fullLast': 'Cole', 'party': 'r', 'house': 'h', 'state': 'OK', 'control': [], 'rights': [55, 59, 62, 64, 67, 71, 90, 93, 94], 'id': 84, 'score': 9, 'pi': 7, 'grade': 'A', 'gi': 5}
#
# Record # 86 :
#  {'first': 'Doug', 'last': 'Collins', 'fullLast': 'Collins', 'party': 'r', 'house': 'h', 'state': 'GA', 'control': [], 'rights': [62, 90], 'id': 85, 'score': 2, 'pi': 3, 'grade': 'A', 'gi': 3}
#
# Record # 87 :
#  {'first': 'Chris', 'last': 'Collins', 'fullLast': 'Collins', 'party': 'r', 'house': 'h', 'state': 'NY', 'control': [], 'rights': [55, 57, 59, 62, 65, 74, 75, 84, 85, 90, 94], 'id': 86, 'score': 11, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 88 :
#  {'first': 'Barbara', 'last': 'Comstock', 'fullLast': 'Comstock', 'party': 'r', 'house': 'h', 'state': 'VA', 'control': [], 'rights': [62], 'id': 87, 'score': 1, 'pi': 4, 'grade': 'A', 'gi': 4}
#
# Record # 89 :
#  {'first': 'Michael', 'last': 'Conaway', 'fullLast': 'Conaway', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [62, 64, 65, 70, 74, 78, 84, 87, 90, 94, 97], 'id': 88, 'score': 11, 'pi': 2, 'grade': 'A', 'gi': 2}
#
# Record # 90 :
#  {'first': 'Gerald', 'last': 'Connolly', 'fullLast': 'Connolly', 'party': 'd', 'house': 'h', 'state': 'VA', 'control': [3, 10, 14, 25, 37, 50], 'rights': [], 'id': 89, 'score': -6, 'pi': 3, 'grade': 'F', 'gi': 3}
#
# Record # 91 :
#  {'first': 'John', 'last': 'Conyers', 'fullLast': 'Conyers', 'party': 'd', 'house': 'h', 'state': 'MI', 'control': [2, 4, 6, 10, 14, 15, 17, 19, 31, 33, 37, 50, 53], 'rights': [], 'id': 90, 'score': -13, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 92 :
#  {'first': 'Paul', 'last': 'Cook', 'fullLast': 'Cook', 'party': 'r', 'house': 'h', 'state': 'CA', 'control': [], 'rights': [57, 62, 63, 64, 65, 74], 'id': 91, 'score': 6, 'pi': 4, 'grade': 'A', 'gi': 4}
#
# Record # 93 :
#  {'first': 'Chris', 'last': 'Coons', 'fullLast': 'Coons', 'party': 'd', 'house': 's', 'state': 'DE', 'control': [11, 44], 'rights': [], 'id': 92, 'score': -2, 'pi': 2, 'grade': 'F', 'gi': 2}
#
# Record # 94 :
#  {'first': 'Jim', 'last': 'Cooper', 'fullLast': 'Cooper', 'party': 'd', 'house': 'h', 'state': 'TN', 'control': [9, 10], 'rights': [75], 'id': 93, 'score': 0, 'pi': 4, 'grade': 'C-', 'gi': 3}
#
# Record # 95 :
#  {'first': 'John', 'last': 'Cornyn', 'fullLast': 'Cornyn', 'party': 'r', 'house': 's', 'state': 'TX', 'control': [], 'rights': [61], 'id': 94, 'score': 1, 'pi': 6, 'grade': 'A+', 'gi': 11}
#
# Record # 96 :
#  {'first': 'Jim', 'last': 'Costa', 'fullLast': 'Costa', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [10], 'rights': [], 'id': 95, 'score': -1, 'pi': 4, 'grade': 'C', 'gi': 1}
#
# Record # 97 :
#  {'first': 'Joe', 'last': 'Courtney', 'fullLast': 'Courtney', 'party': 'd', 'house': 'h', 'state': 'CT', 'control': [9, 10, 14, 17, 31, 50], 'rights': [], 'id': 96, 'score': -6, 'pi': 4, 'grade': 'D', 'gi': 1}
#
# Record # 98 :
#  {'first': 'Kevin', 'last': 'Cramer', 'fullLast': 'Cramer', 'party': 'r', 'house': 'h', 'state': 'ND', 'control': [], 'rights': [55, 57, 59, 62, 65, 67, 71, 74, 78, 90, 94, 95, 97], 'id': 97, 'score': 13, 'pi': 1, 'grade': 'AQ', 'gi': 6}
#
# Record # 99 :
#  {'first': 'Michael', 'last': 'Crapo', 'fullLast': 'Crapo', 'party': 'r', 'house': 's', 'state': 'ID', 'control': [], 'rights': [61, 76, 82, 88, 58, 60, 89], 'id': 98, 'score': 7, 'pi': 0, 'grade': 'A+', 'gi': 0}
#
# Record # 100 :
#  {'first': 'Eric', 'last': 'Crawford', 'fullLast': 'Crawford', 'party': 'r', 'house': 'h', 'state': 'AR', 'control': [], 'rights': [57, 59, 62, 63, 64, 74, 75, 84], 'id': 99, 'score': 8, 'pi': 2, 'grade': 'A', 'gi': 6}
#
# Record # 101 :
#  {'first': 'Ander', 'last': 'Crenshaw', 'fullLast': 'Crenshaw', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [57, 59, 62, 71, 74, 90], 'id': 100, 'score': 6, 'pi': 5, 'grade': 'A', 'gi': 5}
#
# Record # 102 :
#  {'first': 'Joseph', 'last': 'Crowley', 'fullLast': 'Crowley', 'party': 'd', 'house': 'h', 'state': 'NY', 'control': [10, 14, 19, 31, 40, 50, 53], 'rights': [], 'id': 101, 'score': -7, 'pi': 2, 'grade': 'F', 'gi': 2}
#
# Record # 103 :
#  {'first': 'Ted', 'last': 'Cruz', 'fullLast': 'Cruz', 'party': 'r', 'house': 's', 'state': 'TX', 'control': [], 'rights': [61], 'id': 102, 'score': 1, 'pi': 7, 'grade': 'A+', 'gi': 12}
#
# Record # 104 :
#  {'first': 'Henry', 'last': 'Cuellar', 'fullLast': 'Cuellar', 'party': 'd', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [62, 74], 'id': 103, 'score': 2, 'pi': 22, 'grade': 'A-', 'gi': 19}
#
# Record # 105 :
#  {'first': 'John', 'last': 'Culberson', 'fullLast': 'Culberson', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [62, 71, 74, 90, 94], 'id': 104, 'score': 5, 'pi': 5, 'grade': 'A', 'gi': 5}
#
# Record # 106 :
#  {'first': 'Elijah', 'last': 'Cummings', 'fullLast': 'Cummings', 'party': 'd', 'house': 'h', 'state': 'MD', 'control': [1, 2, 10, 13, 14, 17, 24, 31, 37, 40, 50], 'rights': [], 'id': 105, 'score': -11, 'pi': 2, 'grade': 'F', 'gi': 2}
#
# Record # 107 :
#  {'first': 'Carlos', 'last': 'Curbelo', 'fullLast': 'Curbelo', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [62, 78], 'id': 106, 'score': 2, 'pi': 5, 'grade': 'AQ', 'gi': 20}
#
# Record # 108 :
#  {'first': 'Steve', 'last': 'Daines', 'fullLast': 'Daines', 'party': 'r', 'house': 's', 'state': 'MT', 'control': [], 'rights': [60, 61, 88, 76], 'id': 107, 'score': 4, 'pi': 0, 'grade': 'A+', 'gi': 1}
#
# Record # 109 :
#  {'first': 'Rodney', 'last': 'Davis', 'fullLast': 'Davis', 'party': 'r', 'house': 'h', 'state': 'IL', 'control': [], 'rights': [57, 62, 65, 78], 'id': 108, 'score': 4, 'pi': 10, 'grade': 'A', 'gi': 10}
#
# Record # 110 :
#  {'first': 'Susan', 'last': 'Davis', 'fullLast': 'Davis', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [10, 14, 37, 50], 'rights': [], 'id': 109, 'score': -4, 'pi': 9, 'grade': 'F', 'gi': 9}
#
# Record # 111 :
#  {'first': 'Danny', 'last': 'Davis', 'fullLast': 'Davis', 'party': 'd', 'house': 'h', 'state': 'IL', 'control': [4, 6, 10, 15, 37, 50], 'rights': [], 'id': 110, 'score': -6, 'pi': 5, 'grade': 'F', 'gi': 5}
#
# Record # 112 :
#  {'first': 'Peter', 'last': 'DeFazio', 'fullLast': 'DeFazio', 'party': 'd', 'house': 'h', 'state': 'OR', 'control': [10, 29], 'rights': [78], 'id': 111, 'score': 0, 'pi': 5, 'grade': 'Not rated', 'gi': 6}
#
# Record # 113 :
#  {'first': 'Diana', 'last': 'DeGette', 'fullLast': 'DeGette', 'party': 'd', 'house': 'h', 'state': 'CO', 'control': [10, 14, 17, 27, 50], 'rights': [], 'id': 112, 'score': -5, 'pi': 2, 'grade': 'Not rated', 'gi': 9}
#
# Record # 114 :
#  {'first': 'Rosa', 'last': 'DeLauro', 'fullLast': 'DeLauro', 'party': 'd', 'house': 'h', 'state': 'CT', 'control': [9, 10, 14, 15, 19, 24, 27, 37, 50, 13], 'rights': [], 'id': 113, 'score': -10, 'pi': 0, 'grade': 'Not rated', 'gi': 7}
#
# Record # 115 :
#  {'first': 'Ron', 'last': 'DeSantis', 'fullLast': 'DeSantis', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [62, 64], 'id': 114, 'score': 2, 'pi': 6, 'grade': 'Not rated', 'gi': 22}
#
# Record # 116 :
#  {'first': 'Mark', 'last': 'DeSaulnier', 'fullLast': 'DeSaulnier', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [1, 2, 9, 10, 12, 14, 17, 21, 25, 26, 31, 35, 36, 37, 40, 50, 53], 'rights': [], 'id': 115, 'score': -17, 'pi': 1, 'grade': 'Not rated', 'gi': 2}
#
# Record # 117 :
#  {'first': 'Suzan', 'last': 'DelBene', 'fullLast': 'DelBene', 'party': 'd', 'house': 'h', 'state': 'WA', 'control': [9, 10], 'rights': [], 'id': 116, 'score': -2, 'pi': 5, 'grade': 'Not rated', 'gi': 21}
#
# Record # 118 :
#  {'first': 'John', 'last': 'Delaney', 'fullLast': 'Delaney', 'party': 'd', 'house': 'h', 'state': 'MD', 'control': [9, 10, 24, 50], 'rights': [], 'id': 117, 'score': -4, 'pi': 2, 'grade': 'F', 'gi': 5}
#
# Record # 119 :
#  {'first': 'Jeff', 'last': 'Denham', 'fullLast': 'Denham', 'party': 'r', 'house': 'h', 'state': 'CA', 'control': [], 'rights': [62], 'id': 118, 'score': 1, 'pi': 5, 'grade': 'A', 'gi': 5}
#
# Record # 120 :
#  {'first': 'Charles', 'last': 'Dent', 'fullLast': 'Dent', 'party': 'r', 'house': 'h', 'state': 'PA', 'control': [], 'rights': [57, 62], 'id': 119, 'score': 2, 'pi': 7, 'grade': 'A', 'gi': 7}
#
# Record # 121 :
#  {'first': 'Scott', 'last': 'DesJarlais', 'fullLast': 'DesJarlais', 'party': 'r', 'house': 'h', 'state': 'TN', 'control': [], 'rights': [55, 57, 59, 62, 64, 71, 74, 90, 75], 'id': 120, 'score': 9, 'pi': 2, 'grade': 'Not rated', 'gi': 14}
#
# Record # 122 :
#  {'first': 'Theodore', 'last': 'Deutch', 'fullLast': 'Deutch', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [2, 7, 10, 14, 17, 19, 24, 31, 36, 37, 40, 50, 53, 3, 5], 'rights': [], 'id': 121, 'score': -15, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 123 :
#  {'first': 'Mario', 'last': 'Diaz-Balart', 'fullLast': 'Diaz-Balart', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [62], 'id': 122, 'score': 1, 'pi': 6, 'grade': 'Not rated', 'gi': 22}
#
# Record # 124 :
#  {'first': 'Debbie', 'last': 'Dingell', 'fullLast': 'Dingell', 'party': 'd', 'house': 'h', 'state': 'MI', 'control': [10, 33], 'rights': [], 'id': 123, 'score': -2, 'pi': 6, 'grade': 'Not rated', 'gi': 22}
#
# Record # 125 :
#  {'first': 'Lloyd', 'last': 'Doggett', 'fullLast': 'Doggett', 'party': 'd', 'house': 'h', 'state': 'TX', 'control': [10, 50], 'rights': [], 'id': 124, 'score': -2, 'pi': 7, 'grade': 'F', 'gi': 9}
#
# Record # 126 :
#  {'first': 'Bob', 'last': 'Dold', 'fullLast': 'Dold', 'party': 'r', 'house': 'h', 'state': 'IL', 'control': [9, 10, 33, 40], 'rights': [78], 'id': 125, 'score': 0, 'pi': 0, 'grade': 'D', 'gi': 4}
#
# Record # 127 :
#  {'first': 'Daniel', 'last': 'Donovan', 'fullLast': 'Donovan', 'party': 'r', 'house': 'h', 'state': 'NY', 'control': [9, 10, 33, 40], 'rights': [], 'id': 126, 'score': -4, 'pi': 1, 'grade': 'F', 'gi': 10}
#
# Record # 128 :
#  {'first': 'Michael', 'last': 'Doyle', 'fullLast': 'Doyle', 'party': 'd', 'house': 'h', 'state': 'PA', 'control': [9, 10, 14, 19, 27, 37, 50], 'rights': [], 'id': 127, 'score': -7, 'pi': 3, 'grade': 'F', 'gi': 3}
#
# Record # 129 :
#  {'first': 'Tammy', 'last': 'Duckworth', 'fullLast': 'Duckworth', 'party': 'd', 'house': 'h', 'state': 'IL', 'control': [9, 10, 14, 27, 29, 31, 37, 40, 50], 'rights': [], 'id': 128, 'score': -9, 'pi': 3, 'grade': 'F', 'gi': 3}
#
# Record # 130 :
#  {'first': 'Sean', 'last': 'Duffy', 'fullLast': 'Duffy', 'party': 'r', 'house': 'h', 'state': 'WI', 'control': [], 'rights': [55, 62, 65, 75], 'id': 129, 'score': 4, 'pi': 2, 'grade': 'A', 'gi': 2}
#
# Record # 131 :
#  {'first': 'John', 'last': 'Duncan', 'fullLast': 'Duncan', 'party': 'r', 'house': 'h', 'state': 'TN', 'control': [], 'rights': [57, 59, 62, 64, 65, 75, 90, 93, 94], 'id': 130, 'score': 9, 'pi': 3, 'grade': 'A', 'gi': 2}
#
# Record # 132 :
#  {'first': 'Jeff', 'last': 'Duncan', 'fullLast': 'Duncan', 'party': 'r', 'house': 'h', 'state': 'SC', 'control': [], 'rights': [55, 56, 57, 62, 64, 74, 75, 84, 90, 93, 95], 'id': 131, 'score': 11, 'pi': 3, 'grade': 'A', 'gi': 3}
#
# Record # 133 :
#  {'first': 'Richard', 'last': 'Durbin', 'fullLast': 'Durbin', 'party': 'd', 'house': 's', 'state': 'IL', 'control': [8, 11, 23, 32, 34, 42, 44], 'rights': [], 'id': 132, 'score': -7, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 134 :
#  {'first': 'Donna', 'last': 'Edwards', 'fullLast': 'Edwards', 'party': 'd', 'house': 'h', 'state': 'MD', 'control': [1, 2, 9, 10, 13, 14, 15, 17, 19, 21, 29, 31, 37, 43, 50, 51], 'rights': [], 'id': 133, 'score': -16, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 135 :
#  {'first': 'Keith', 'last': 'Ellison', 'fullLast': 'Ellison', 'party': 'd', 'house': 'h', 'state': 'MN', 'control': [1, 10, 12, 13, 14, 15, 20, 26, 27, 29, 31, 37, 50, 53], 'rights': [], 'id': 134, 'score': -14, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 136 :
#  {'first': 'Renee', 'last': 'Ellmers', 'fullLast': 'Ellmers', 'party': 'r', 'house': 'h', 'state': 'NC', 'control': [], 'rights': [55, 57, 59, 62, 90], 'id': 135, 'score': 5, 'pi': 6, 'grade': 'A', 'gi': 6}
#
# Record # 137 :
#  {'first': 'Tom', 'last': 'Emmer', 'fullLast': 'Emmer', 'party': 'r', 'house': 'h', 'state': 'MN', 'control': [], 'rights': [62, 64, 65, 74, 90], 'id': 136, 'score': 5, 'pi': 7, 'grade': 'A', 'gi': 7}
#
# Record # 138 :
#  {'first': 'Eliot', 'last': 'Engel', 'fullLast': 'Engel', 'party': 'd', 'house': 'h', 'state': 'NY', 'control': [10, 14, 17, 19, 20, 25, 26, 27, 29, 31, 35, 37, 40, 46, 50, 51, 53, 12], 'rights': [], 'id': 137, 'score': -18, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 139 :
#  {'first': 'Michael', 'last': 'Enzi', 'fullLast': 'Enzi', 'party': 'r', 'house': 's', 'state': 'WY', 'control': [], 'rights': [60, 61, 88], 'id': 138, 'score': 3, 'pi': 0, 'grade': 'A', 'gi': 0}
#
# Record # 140 :
#  {'first': 'Joni', 'last': 'Ernst', 'fullLast': 'Ernst', 'party': 'r', 'house': 's', 'state': 'IA', 'control': [], 'rights': [60, 61], 'id': 139, 'score': 2, 'pi': 2, 'grade': 'A', 'gi': 1}
#
# Record # 141 :
#  {'first': 'Anna', 'last': 'Eshoo', 'fullLast': 'Eshoo', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [9, 10, 14, 15, 17, 29, 31, 37, 40, 50], 'rights': [], 'id': 140, 'score': -10, 'pi': 1, 'grade': 'F', 'gi': 0}
#
# Record # 142 :
#  {'first': 'Elizabeth', 'last': 'Esty', 'fullLast': 'Esty', 'party': 'd', 'house': 'h', 'state': 'CT', 'control': [9, 10, 15, 17, 19, 24, 27, 29, 31, 37, 50, 53, 14], 'rights': [], 'id': 141, 'score': -13, 'pi': 2, 'grade': 'F', 'gi': 2}
#
# Record # 143 :
#  {'first': 'Blake', 'last': 'Farenthold', 'fullLast': 'Farenthold', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [55, 57, 59, 62, 63, 64, 65, 69, 74, 75, 90, 97], 'id': 142, 'score': 12, 'pi': 0, 'grade': 'A', 'gi': 0}
#
# Record # 144 :
#  {'first': 'Sam', 'last': 'Farr', 'fullLast': 'Farr', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [2, 9, 10, 14, 15, 17, 19, 25, 27, 31, 35, 37, 50, 53], 'rights': [], 'id': 143, 'score': -14, 'pi': 2, 'grade': 'F', 'gi': 2}
#
# Record # 145 :
#  {'first': 'Chaka', 'last': 'Fattah', 'fullLast': 'Fattah', 'party': 'd', 'house': 'h', 'state': 'PA', 'control': [2, 10, 14, 15, 17, 29, 37, 50, 51], 'rights': [], 'id': 144, 'score': -9, 'pi': 4, 'grade': 'F', 'gi': 4}
#
# Record # 146 :
#  {'first': 'Dianne', 'last': 'Feinstein', 'fullLast': 'Feinstein', 'party': 'd', 'house': 's', 'state': 'CA', 'control': [8, 38, 44, 11], 'rights': [], 'id': 145, 'score': -4, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 147 :
#  {'first': 'Stephen', 'last': 'Fincher', 'fullLast': 'Fincher', 'party': 'r', 'house': 'h', 'state': 'TN', 'control': [], 'rights': [55, 57, 62, 63, 67, 75, 90, 94], 'id': 146, 'score': 8, 'pi': 3, 'grade': 'A', 'gi': 2}
#
# Record # 148 :
#  {'first': 'Deb', 'last': 'Fischer', 'fullLast': 'Fischer', 'party': 'r', 'house': 's', 'state': 'NE', 'control': [], 'rights': [61, 92], 'id': 147, 'score': 2, 'pi': 3, 'grade': 'A', 'gi': 2}
#
# Record # 149 :
#  {'first': 'Michael', 'last': 'Fitzpatrick', 'fullLast': 'Fitzpatrick', 'party': 'r', 'house': 'h', 'state': 'PA', 'control': [10, 40], 'rights': [], 'id': 148, 'score': -2, 'pi': 0, 'grade': 'B-', 'gi': 2}
#
# Record # 150 :
#  {'first': 'Charles', 'last': 'Fleischmann', 'fullLast': 'Fleischmann', 'party': 'r', 'house': 'h', 'state': 'TN', 'control': [], 'rights': [59, 62, 64, 74, 75, 90], 'id': 149, 'score': 6, 'pi': 6, 'grade': 'A', 'gi': 6}
#
# Record # 151 :
#  {'first': 'John', 'last': 'Fleming', 'fullLast': 'Fleming', 'party': 'r', 'house': 'h', 'state': 'LA', 'control': [], 'rights': [57, 59, 62, 64, 74, 84, 94], 'id': 150, 'score': 7, 'pi': 5, 'grade': 'A', 'gi': 5}
#
# Record # 152 :
#  {'first': 'Bill', 'last': 'Flores', 'fullLast': 'Flores', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [62, 65, 87, 90, 93, 94], 'id': 151, 'score': 6, 'pi': 7, 'grade': 'A', 'gi': 7}
#
# Record # 153 :
#  {'first': 'Randy', 'last': 'Forbes', 'fullLast': 'Forbes', 'party': 'r', 'house': 'h', 'state': 'VA', 'control': [], 'rights': [55, 59, 62, 90], 'id': 152, 'score': 4, 'pi': 3, 'grade': 'A+', 'gi': 15}
#
# Record # 154 :
#  {'first': 'Jeff', 'last': 'Fortenberry', 'fullLast': 'Fortenberry', 'party': 'r', 'house': 'h', 'state': 'NE', 'control': [], 'rights': [55, 78], 'id': 153, 'score': 2, 'pi': 8, 'grade': 'A', 'gi': 8}
#
# Record # 155 :
#  {'first': 'Bill', 'last': 'Foster', 'fullLast': 'Foster', 'party': 'd', 'house': 'h', 'state': 'IL', 'control': [9, 10, 15, 50], 'rights': [], 'id': 154, 'score': -4, 'pi': 4, 'grade': 'D', 'gi': 3}
#
# Record # 156 :
#  {'first': 'Virginia', 'last': 'Foxx', 'fullLast': 'Foxx', 'party': 'r', 'house': 'h', 'state': 'NC', 'control': [], 'rights': [62, 75, 90], 'id': 155, 'score': 3, 'pi': 3, 'grade': 'A', 'gi': 3}
#
# Record # 157 :
#  {'first': 'Lois', 'last': 'Frankel', 'fullLast': 'Frankel', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [9, 10, 14, 17, 19, 35, 37, 40, 50], 'rights': [], 'id': 156, 'score': -9, 'pi': 5, 'grade': 'F', 'gi': 5}
#
# Record # 158 :
#  {'first': 'Alan', 'last': 'Franken', 'fullLast': 'Franken', 'party': 'd', 'house': 's', 'state': 'MN', 'control': [8, 11], 'rights': [], 'id': 157, 'score': -2, 'pi': 3, 'grade': 'F', 'gi': 3}
#
# Record # 159 :
#  {'first': 'Trent', 'last': 'Franks', 'fullLast': 'Franks', 'party': 'r', 'house': 'h', 'state': 'AZ', 'control': [], 'rights': [55, 57, 59, 62, 64, 65, 74, 90, 93, 94, 95], 'id': 158, 'score': 11, 'pi': 4, 'grade': 'A', 'gi': 4}
#
# Record # 160 :
#  {'first': 'Marcia', 'last': 'Fudge', 'fullLast': 'Fudge', 'party': 'd', 'house': 'h', 'state': 'OH', 'control': [10, 14, 27, 31, 37, 50, 51], 'rights': [], 'id': 159, 'score': -7, 'pi': 4, 'grade': 'F', 'gi': 4}
#
# Record # 161 :
#  {'first': 'Tulsi', 'last': 'Gabbard', 'fullLast': 'Gabbard', 'party': 'd', 'house': 'h', 'state': 'HI', 'control': [10], 'rights': [], 'id': 160, 'score': -1, 'pi': 5, 'grade': 'F', 'gi': 7}
#
# Record # 162 :
#  {'first': 'Ruben', 'last': 'Gallego', 'fullLast': 'Gallego', 'party': 'd', 'house': 'h', 'state': 'AZ', 'control': [10, 14, 37, 50], 'rights': [], 'id': 161, 'score': -4, 'pi': 5, 'grade': 'F', 'gi': 6}
#
# Record # 163 :
#  {'first': 'John', 'last': 'Garamendi', 'fullLast': 'Garamendi', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [9, 10, 37], 'rights': [], 'id': 162, 'score': -3, 'pi': 2, 'grade': 'F', 'gi': 7}
#
# Record # 164 :
#  {'first': 'Cory', 'last': 'Gardner', 'fullLast': 'Gardner', 'party': 'r', 'house': 's', 'state': 'CO', 'control': [], 'rights': [76], 'id': 163, 'score': 1, 'pi': 8, 'grade': 'A', 'gi': 4}
#
# Record # 165 :
#  {'first': 'Bob', 'last': 'Gibbs', 'fullLast': 'Gibbs', 'party': 'r', 'house': 'h', 'state': 'OH', 'control': [], 'rights': [62, 64, 74, 90, 94, 95, 59], 'id': 164, 'score': 7, 'pi': 6, 'grade': 'A+', 'gi': 21}
#
# Record # 166 :
#  {'first': 'Christopher', 'last': 'Gibson', 'fullLast': 'Gibson', 'party': 'r', 'house': 'h', 'state': 'NY', 'control': [], 'rights': [57, 59, 62, 65, 71, 74, 78, 90], 'id': 165, 'score': 8, 'pi': 4, 'grade': 'A', 'gi': 3}
#
# Record # 167 :
#  {'first': 'Kirsten', 'last': 'Gillibrand', 'fullLast': 'Gillibrand', 'party': 'd', 'house': 's', 'state': 'NY', 'control': [8, 11, 22, 34, 38, 39, 41, 42, 44, 32], 'rights': [], 'id': 166, 'score': -10, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 168 :
#  {'first': 'Louie', 'last': 'Gohmert', 'fullLast': 'Gohmert', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [56, 62, 64, 90, 93], 'id': 167, 'score': 5, 'pi': 8, 'grade': 'A', 'gi': 8}
#
# Record # 169 :
#  {'first': 'Bob', 'last': 'Goodlatte', 'fullLast': 'Goodlatte', 'party': 'r', 'house': 'h', 'state': 'VA', 'control': [], 'rights': [75, 78], 'id': 168, 'score': 2, 'pi': 9, 'grade': 'A+', 'gi': 18}
#
# Record # 170 :
#  {'first': 'Paul', 'last': 'Gosar', 'fullLast': 'Gosar', 'party': 'r', 'house': 'h', 'state': 'AZ', 'control': [], 'rights': [55, 57, 59, 62, 63, 64, 65, 74, 75, 93, 94, 95, 97], 'id': 169, 'score': 13, 'pi': 2, 'grade': 'A', 'gi': 1}
#
# Record # 171 :
#  {'first': 'Trey', 'last': 'Gowdy', 'fullLast': 'Gowdy', 'party': 'r', 'house': 'h', 'state': 'SC', 'control': [], 'rights': [57, 62, 64], 'id': 170, 'score': 3, 'pi': 4, 'grade': 'A', 'gi': 4}
#
# Record # 172 :
#  {'first': 'Gwen', 'last': 'Graham', 'fullLast': 'Graham', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [9, 10], 'rights': [], 'id': 171, 'score': -2, 'pi': 9, 'grade': 'Not rated', 'gi': 20}
#
# Record # 173 :
#  {'first': 'Lindsey', 'last': 'Graham', 'fullLast': 'Graham', 'party': 'r', 'house': 's', 'state': 'SC', 'control': [], 'rights': [61], 'id': 172, 'score': 1, 'pi': 0, 'grade': 'A-', 'gi': 13}
#
# Record # 174 :
#  {'first': 'Kay', 'last': 'Granger', 'fullLast': 'Granger', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [62, 90], 'id': 173, 'score': 2, 'pi': 10, 'grade': 'A', 'gi': 10}
#
# Record # 175 :
#  {'first': 'Charles', 'last': 'Grassley', 'fullLast': 'Grassley', 'party': 'r', 'house': 's', 'state': 'IA', 'control': [], 'rights': [61, 76], 'id': 174, 'score': 2, 'pi': 4, 'grade': 'A', 'gi': 3}
#
# Record # 176 :
#  {'first': 'Garret', 'last': 'Graves', 'fullLast': 'Graves', 'party': 'r', 'house': 'h', 'state': 'LA', 'control': [], 'rights': [62], 'id': 175, 'score': 1, 'pi': 7, 'grade': 'AQ', 'gi': 18}
#
# Record # 177 :
#  {'first': 'Sam', 'last': 'Graves', 'fullLast': 'Graves', 'party': 'r', 'house': 'h', 'state': 'MO', 'control': [], 'rights': [55, 59, 62, 71, 94, 96], 'id': 176, 'score': 6, 'pi': 8, 'grade': 'A', 'gi': 8}
#
# Record # 178 :
#  {'first': 'Tom', 'last': 'Graves', 'fullLast': 'Graves', 'party': 'r', 'house': 'h', 'state': 'GA', 'control': [], 'rights': [55, 57, 59, 62, 64, 74, 75, 90], 'id': 177, 'score': 8, 'pi': 5, 'grade': 'A+', 'gi': 13}
#
# Record # 179 :
#  {'first': 'Alan', 'last': 'Grayson', 'fullLast': 'Grayson', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [10, 14, 50, 53], 'rights': [], 'id': 178, 'score': -4, 'pi': 6, 'grade': 'F', 'gi': 11}
#
# Record # 180 :
#  {'first': 'Gene', 'last': 'Green', 'fullLast': 'Green', 'party': 'd', 'house': 'h', 'state': 'TX', 'control': [9], 'rights': [57, 62], 'id': 179, 'score': 0, 'pi': 6, 'grade': 'A-', 'gi': 1}
#
# Record # 181 :
#  {'first': 'Al', 'last': 'Green', 'fullLast': 'Green', 'party': 'd', 'house': 'h', 'state': 'TX', 'control': [9, 10, 31, 50, 51, 53], 'rights': [], 'id': 180, 'score': -6, 'pi': 6, 'grade': 'F', 'gi': 6}
#
# Record # 182 :
#  {'first': 'Morgan', 'last': 'Griffith', 'fullLast': 'Griffith', 'party': 'r', 'house': 'h', 'state': 'VA', 'control': [], 'rights': [56, 62, 84, 90, 55], 'id': 181, 'score': 5, 'pi': 9, 'grade': 'A+', 'gi': 24}
#
# Record # 183 :
#  {'first': 'Ra&#xFA;l', 'last': 'Grijalva', 'fullLast': 'Grijalva', 'party': 'd', 'house': 'h', 'state': 'AZ', 'control': [1, 2, 6, 7, 10, 12, 13, 14, 15, 17, 19, 20, 21, 26, 27, 29, 31, 36, 37, 50], 'rights': [], 'id': 182, 'score': -20, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 184 :
#  {'first': 'Glenn', 'last': 'Grothman', 'fullLast': 'Grothman', 'party': 'r', 'house': 'h', 'state': 'WI', 'control': [], 'rights': [55, 57, 59, 62, 63, 65, 78, 84, 90, 93, 94, 95], 'id': 183, 'score': 12, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 185 :
#  {'first': 'Frank', 'last': 'Guinta', 'fullLast': 'Guinta', 'party': 'r', 'house': 'h', 'state': 'NH', 'control': [], 'rights': [59, 62, 64, 69, 74, 75, 94], 'id': 184, 'score': 7, 'pi': 7, 'grade': 'A', 'gi': 7}
#
# Record # 186 :
#  {'first': 'Brett', 'last': 'Guthrie', 'fullLast': 'Guthrie', 'party': 'r', 'house': 'h', 'state': 'KY', 'control': [], 'rights': [57, 59, 62, 78, 90], 'id': 185, 'score': 5, 'pi': 10, 'grade': 'A', 'gi': 10}
#
# Record # 187 :
#  {'first': 'Luis', 'last': 'Gutierrez', 'fullLast': 'Gutierrez', 'party': 'd', 'house': 'h', 'state': 'IL', 'control': [1, 9, 10, 13, 19, 20, 21, 26, 37, 50, 53], 'rights': [], 'id': 186, 'score': -11, 'pi': 3, 'grade': 'F', 'gi': 3}
#
# Record # 188 :
#  {'first': 'Janice', 'last': 'Hahn', 'fullLast': 'Hahn', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [1, 2, 9, 10, 14, 15, 17, 27, 37, 50], 'rights': [], 'id': 187, 'score': -10, 'pi': 2, 'grade': 'F', 'gi': 1}
#
# Record # 189 :
#  {'first': 'Richard', 'last': 'Hanna', 'fullLast': 'Hanna', 'party': 'r', 'house': 'h', 'state': 'NY', 'control': [], 'rights': [55, 57, 59, 62, 65, 74, 84], 'id': 188, 'score': 7, 'pi': 8, 'grade': 'A', 'gi': 8}
#
# Record # 190 :
#  {'first': 'Cresent', 'last': 'Hardy', 'fullLast': 'Hardy', 'party': 'r', 'house': 'h', 'state': 'NV', 'control': [], 'rights': [59, 62, 75, 90], 'id': 189, 'score': 4, 'pi': 4, 'grade': 'A', 'gi': 4}
#
# Record # 191 :
#  {'first': 'Gregg', 'last': 'Harper', 'fullLast': 'Harper', 'party': 'r', 'house': 'h', 'state': 'MS', 'control': [], 'rights': [59, 62, 74, 90, 94, 95], 'id': 190, 'score': 6, 'pi': 9, 'grade': 'A', 'gi': 9}
#
# Record # 192 :
#  {'first': 'Andy', 'last': 'Harris', 'fullLast': 'Harris', 'party': 'r', 'house': 'h', 'state': 'MD', 'control': [], 'rights': [59, 62, 64, 74, 77, 87, 90, 94, 95], 'id': 191, 'score': 9, 'pi': 4, 'grade': 'A', 'gi': 3}
#
# Record # 193 :
#  {'first': 'Vicky', 'last': 'Hartzler', 'fullLast': 'Hartzler', 'party': 'r', 'house': 'h', 'state': 'MO', 'control': [], 'rights': [62, 63, 74, 78, 90], 'id': 192, 'score': 5, 'pi': 11, 'grade': 'A', 'gi': 11}
#
# Record # 194 :
#  {'first': 'Alcee', 'last': 'Hastings', 'fullLast': 'Hastings', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [2, 4, 6, 9, 10, 14, 15, 17, 19, 25, 26, 31, 36, 37, 50, 53], 'rights': [], 'id': 193, 'score': -16, 'pi': 2, 'grade': 'F', 'gi': 2}
#
# Record # 195 :
#  {'first': 'Orrin', 'last': 'Hatch', 'fullLast': 'Hatch', 'party': 'r', 'house': 's', 'state': 'UT', 'control': [], 'rights': [60, 61], 'id': 194, 'score': 2, 'pi': 5, 'grade': 'A+', 'gi': 8}
#
# Record # 196 :
#  {'first': 'Denny', 'last': 'Heck', 'fullLast': 'Heck', 'party': 'd', 'house': 'h', 'state': 'WA', 'control': [9, 10], 'rights': [], 'id': 195, 'score': -2, 'pi': 10, 'grade': 'C', 'gi': 3}
#
# Record # 197 :
#  {'first': 'Joseph', 'last': 'Heck', 'fullLast': 'Heck', 'party': 'r', 'house': 'h', 'state': 'NV', 'control': [], 'rights': [57, 62, 66, 74, 78, 90], 'id': 196, 'score': 6, 'pi': 10, 'grade': 'A', 'gi': 10}
#
# Record # 198 :
#  {'first': 'Martin', 'last': 'Heinrich', 'fullLast': 'Heinrich', 'party': 'd', 'house': 's', 'state': 'NM', 'control': [11], 'rights': [], 'id': 197, 'score': -1, 'pi': 3, 'grade': 'Not rated', 'gi': 9}
#
# Record # 199 :
#  {'first': 'Dean', 'last': 'Heller', 'fullLast': 'Heller', 'party': 'r', 'house': 's', 'state': 'NV', 'control': [], 'rights': [60, 61, 79], 'id': 198, 'score': 3, 'pi': 1, 'grade': 'A', 'gi': 1}
#
# Record # 200 :
#  {'first': 'Jeb', 'last': 'Hensarling', 'fullLast': 'Hensarling', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [55, 57, 59, 62, 64, 65, 74, 75, 84, 90], 'id': 199, 'score': 10, 'pi': 4, 'grade': 'A', 'gi': 3}
#
# Record # 201 :
#  {'first': 'Jaime', 'last': 'Beutler', 'fullLast': 'Herrera Beutler', 'party': 'r', 'house': 'h', 'state': 'WA', 'control': [], 'rights': [57, 62], 'id': 200, 'score': 2, 'pi': 0, 'grade': 'A', 'gi': 0}
#
# Record # 202 :
#  {'first': 'Jody', 'last': 'Hice', 'fullLast': 'Hice', 'party': 'r', 'house': 'h', 'state': 'GA', 'control': [], 'rights': [62, 63, 64, 71, 74, 75, 87, 90, 93, 94, 95, 77], 'id': 201, 'score': 12, 'pi': 2, 'grade': 'AQ', 'gi': 7}
#
# Record # 203 :
#  {'first': 'Brian', 'last': 'Higgins', 'fullLast': 'Higgins', 'party': 'd', 'house': 'h', 'state': 'NY', 'control': [10, 18, 50], 'rights': [], 'id': 202, 'score': -3, 'pi': 3, 'grade': 'C', 'gi': 1}
#
# Record # 204 :
#  {'first': 'French', 'last': 'Hill', 'fullLast': 'Hill', 'party': 'r', 'house': 'h', 'state': 'AR', 'control': [], 'rights': [57, 62, 65, 78, 90], 'id': 203, 'score': 5, 'pi': 12, 'grade': 'A', 'gi': 12}
#
# Record # 205 :
#  {'first': 'James', 'last': 'Himes', 'fullLast': 'Himes', 'party': 'd', 'house': 'h', 'state': 'CT', 'control': [2, 9, 10, 14, 15, 17, 27, 29, 37, 40, 50], 'rights': [], 'id': 204, 'score': -11, 'pi': 4, 'grade': 'F', 'gi': 4}
#
# Record # 206 :
#  {'first': 'Rub&#xE9;n', 'last': 'Hinojosa', 'fullLast': 'Hinojosa', 'party': 'd', 'house': 'h', 'state': 'TX', 'control': [9, 10, 14], 'rights': [], 'id': 205, 'score': -3, 'pi': 4, 'grade': 'D', 'gi': 4}
#
# Record # 207 :
#  {'first': 'Mazie', 'last': 'Hirono', 'fullLast': 'Hirono', 'party': 'd', 'house': 's', 'state': 'HI', 'control': [8, 11, 23, 34, 44], 'rights': [], 'id': 206, 'score': -5, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 208 :
#  {'first': 'John', 'last': 'Hoeven', 'fullLast': 'Hoeven', 'party': 'r', 'house': 's', 'state': 'ND', 'control': [], 'rights': [61], 'id': 207, 'score': 1, 'pi': 10, 'grade': 'A', 'gi': 5}
#
# Record # 209 :
#  {'first': 'George', 'last': 'Holding', 'fullLast': 'Holding', 'party': 'r', 'house': 'h', 'state': 'NC', 'control': [], 'rights': [62, 90], 'id': 208, 'score': 2, 'pi': 12, 'grade': 'A', 'gi': 12}
#
# Record # 210 :
#  {'first': 'Michael', 'last': 'Honda', 'fullLast': 'Honda', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [2, 9, 10, 14, 15, 17, 24, 35, 37, 50, 53, 4, 6], 'rights': [], 'id': 209, 'score': -13, 'pi': 3, 'grade': 'F', 'gi': 3}
#
# Record # 211 :
#  {'first': 'Steny', 'last': 'Hoyer', 'fullLast': 'Hoyer', 'party': 'd', 'house': 'h', 'state': 'MD', 'control': [10, 14, 50], 'rights': [], 'id': 210, 'score': -3, 'pi': 5, 'grade': 'F', 'gi': 8}
#
# Record # 212 :
# ...
#
# Record # 434 :
#  {'first': 'Lamar', 'last': 'Smith', 'fullLast': 'Smith', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [57, 62, 64, 74, 75, 90, 97], 'id': 433, 'score': 7, 'pi': 17, 'grade': 'AQ', 'gi': 22}
#
# Record # 435 :
#  {'first': 'Christopher', 'last': 'Smith', 'fullLast': 'Smith', 'party': 'r', 'house': 'h', 'state': 'NJ', 'control': [], 'rights': [62], 'id': 434, 'score': 1, 'pi': 18, 'grade': 'C+', 'gi': 20}
#
# Record # 436 :
#  {'first': 'Jason', 'last': 'Smith', 'fullLast': 'Smith', 'party': 'r', 'house': 'h', 'state': 'MO', 'control': [], 'rights': [57, 59, 62, 64, 71, 75, 90], 'id': 435, 'score': 7, 'pi': 18, 'grade': 'A', 'gi': 18}
#
# Record # 437 :
#  {'first': 'Jackie', 'last': 'Speier', 'fullLast': 'Speier', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [10, 12, 14, 15, 17, 24, 25, 50, 51, 53, 37], 'rights': [], 'id': 436, 'score': -11, 'pi': 5, 'grade': 'F', 'gi': 5}
#
# Record # 438 :
#  {'first': 'Elise', 'last': 'Stefanik', 'fullLast': 'Stefanik', 'party': 'r', 'house': 'h', 'state': 'NY', 'control': [], 'rights': [55, 59, 62, 71, 90], 'id': 437, 'score': 5, 'pi': 23, 'grade': 'AQ', 'gi': 25}
#
# Record # 439 :
#  {'first': 'Chris', 'last': 'Stewart', 'fullLast': 'Stewart', 'party': 'r', 'house': 'h', 'state': 'UT', 'control': [], 'rights': [55, 57, 62, 64, 71, 74], 'id': 438, 'score': 6, 'pi': 19, 'grade': 'A', 'gi': 19}
#
# Record # 440 :
#  {'first': 'Steve', 'last': 'Stivers', 'fullLast': 'Stivers', 'party': 'r', 'house': 'h', 'state': 'OH', 'control': [], 'rights': [62, 64], 'id': 439, 'score': 2, 'pi': 19, 'grade': 'A', 'gi': 6}
#
# Record # 441 :
#  {'first': 'Marlin', 'last': 'Stutzman', 'fullLast': 'Stutzman', 'party': 'r', 'house': 'h', 'state': 'IN', 'control': [], 'rights': [62, 63, 74, 75, 90, 95, 64, 94], 'id': 440, 'score': 8, 'pi': 21, 'grade': 'A+', 'gi': 14}
#
# Record # 442 :
#  {'first': 'Dan', 'last': 'Sullivan', 'fullLast': 'Sullivan', 'party': 'r', 'house': 's', 'state': 'AK', 'control': [], 'rights': [60, 61], 'id': 441, 'score': 2, 'pi': 10, 'grade': 'AQ', 'gi': 10}
#
# Record # 443 :
#  {'first': 'Eric', 'last': 'Swalwell', 'fullLast': 'Swalwell', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [4, 6, 9, 10, 13, 14, 15, 27, 29, 31, 37, 50], 'rights': [], 'id': 442, 'score': -12, 'pi': 4, 'grade': 'F', 'gi': 4}
#
# Record # 444 :
#  {'first': 'Mark', 'last': 'Takai', 'fullLast': 'Takai', 'party': 'd', 'house': 'h', 'state': 'HI', 'control': [10, 14, 15, 19, 27, 35, 37], 'rights': [], 'id': 443, 'score': -7, 'pi': 13, 'grade': 'F', 'gi': 13}
#
# Record # 445 :
#  {'first': 'Mark', 'last': 'Takano', 'fullLast': 'Takano', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [9, 10, 14, 15, 19, 20, 29, 31, 37, 47, 50, 51, 53], 'rights': [], 'id': 444, 'score': -13, 'pi': 6, 'grade': 'F', 'gi': 6}
#
# Record # 446 :
#  {'first': 'Mike', 'last': 'Thompson', 'fullLast': 'Thompson', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [7, 9, 10, 31, 40, 53, 29], 'rights': [], 'id': 445, 'score': -7, 'pi': 14, 'grade': 'F', 'gi': 14}
#
# Record # 447 :
#  {'first': 'Glenn', 'last': 'Thompson', 'fullLast': 'Thompson', 'party': 'r', 'house': 'h', 'state': 'PA', 'control': [], 'rights': [57, 62, 64, 74, 75, 78, 90], 'id': 446, 'score': 7, 'pi': 19, 'grade': 'A', 'gi': 17}
#
# Record # 448 :
#  {'first': 'Bennie', 'last': 'Thompson', 'fullLast': 'Thompson', 'party': 'd', 'house': 'h', 'state': 'MS', 'control': [10, 46], 'rights': [], 'id': 447, 'score': -2, 'pi': 20, 'grade': 'F', 'gi': 14}
#
# Record # 449 :
#  {'first': 'Mac', 'last': 'Thornberry', 'fullLast': 'Thornberry', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [62, 90], 'id': 448, 'score': 2, 'pi': 20, 'grade': 'A', 'gi': 5}
#
# Record # 450 :
#  {'first': 'John', 'last': 'Thune', 'fullLast': 'Thune', 'party': 'r', 'house': 's', 'state': 'SD', 'control': [], 'rights': [61, 88], 'id': 449, 'score': 2, 'pi': 11, 'grade': 'A+', 'gi': 6}
#
# Record # 451 :
#  {'first': 'Patrick', 'last': 'Tiberi', 'fullLast': 'Tiberi', 'party': 'r', 'house': 'h', 'state': 'OH', 'control': [], 'rights': [55, 59, 90], 'id': 450, 'score': 3, 'pi': 18, 'grade': 'A', 'gi': 9}
#
# Record # 452 :
#  {'first': 'Scott', 'last': 'Tipton', 'fullLast': 'Tipton', 'party': 'r', 'house': 'h', 'state': 'CO', 'control': [], 'rights': [57, 62, 64, 74], 'id': 451, 'score': 4, 'pi': 18, 'grade': 'A', 'gi': 3}
#
# Record # 453 :
#  {'first': 'Dina', 'last': 'Titus', 'fullLast': 'Titus', 'party': 'd', 'house': 'h', 'state': 'NV', 'control': [10, 15, 50], 'rights': [], 'id': 452, 'score': -3, 'pi': 14, 'grade': 'C-', 'gi': 3}
#
# Record # 454 :
#  {'first': 'Paul', 'last': 'Tonko', 'fullLast': 'Tonko', 'party': 'd', 'house': 'h', 'state': 'NY', 'control': [9, 10, 14, 37, 50], 'rights': [], 'id': 453, 'score': -5, 'pi': 8, 'grade': 'F', 'gi': 8}
#
# Record # 455 :
#  {'first': 'Patrick', 'last': 'Toomey', 'fullLast': 'Toomey', 'party': 'r', 'house': 's', 'state': 'PA', 'control': [], 'rights': [61], 'id': 454, 'score': 1, 'pi': 13, 'grade': 'A', 'gi': 2}
#
# Record # 456 :
#  {'first': 'Norma', 'last': 'Torres', 'fullLast': 'Torres', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [9, 10, 50], 'rights': [], 'id': 455, 'score': -3, 'pi': 15, 'grade': 'F', 'gi': 10}
#
# Record # 457 :
#  {'first': 'Dave', 'last': 'Trott', 'fullLast': 'Trott', 'party': 'r', 'house': 'h', 'state': 'MI', 'control': [], 'rights': [62], 'id': 456, 'score': 1, 'pi': 19, 'grade': 'AQ', 'gi': 17}
#
# Record # 458 :
#  {'first': 'Niki', 'last': 'Tsongas', 'fullLast': 'Tsongas', 'party': 'd', 'house': 'h', 'state': 'MA', 'control': [9, 10, 14, 20, 21, 25, 26, 27, 29, 31, 36, 37, 46, 50, 53], 'rights': [], 'id': 457, 'score': -15, 'pi': 4, 'grade': 'F', 'gi': 4}
#
# Record # 459 :
#  {'first': 'Michael', 'last': 'Turner', 'fullLast': 'Turner', 'party': 'r', 'house': 'h', 'state': 'OH', 'control': [], 'rights': [57, 59, 62], 'id': 458, 'score': 3, 'pi': 12, 'grade': 'A', 'gi': 7}
#
# Record # 460 :
#  {'first': 'Tom', 'last': 'Udall', 'fullLast': 'Udall', 'party': 'd', 'house': 's', 'state': 'NM', 'control': [11], 'rights': [], 'id': 459, 'score': -1, 'pi': 8, 'grade': 'D', 'gi': 2}
#
# Record # 461 :
#  {'first': 'Fred', 'last': 'Upton', 'fullLast': 'Upton', 'party': 'r', 'house': 'h', 'state': 'MI', 'control': [], 'rights': [57, 62], 'id': 460, 'score': 2, 'pi': 4, 'grade': 'A', 'gi': 4}
#
# Record # 462 :
#  {'first': 'David', 'last': 'Valadao', 'fullLast': 'Valadao', 'party': 'r', 'house': 'h', 'state': 'CA', 'control': [], 'rights': [55, 57, 62, 63, 74, 78, 90], 'id': 461, 'score': 7, 'pi': 20, 'grade': 'A', 'gi': 16}
#
# Record # 463 :
#  {'first': 'Chris', 'last': 'Hollen', 'fullLast': 'Van Hollen', 'party': 'd', 'house': 'h', 'state': 'MD', 'control': [1, 2, 7, 9, 10, 13, 14, 15, 17, 19, 20, 25, 27, 29, 31, 37, 45, 50, 51, 53, 24], 'rights': [], 'id': 462, 'score': -21, 'pi': 0, 'grade': 'F', 'gi': 0}
#
# Record # 464 :
#  {'first': 'Juan', 'last': 'Vargas', 'fullLast': 'Vargas', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [9, 10, 37, 50, 53], 'rights': [], 'id': 463, 'score': -5, 'pi': 9, 'grade': 'F', 'gi': 2}
#
# Record # 465 :
#  {'first': 'Marc', 'last': 'Veasey', 'fullLast': 'Veasey', 'party': 'd', 'house': 'h', 'state': 'TX', 'control': [1, 10, 50], 'rights': [], 'id': 464, 'score': -3, 'pi': 16, 'grade': 'C-', 'gi': 2}
#
# Record # 466 :
#  {'first': 'Nydia', 'last': 'Velazquez', 'fullLast': 'Velazquez', 'party': 'd', 'house': 'h', 'state': 'NY', 'control': [10, 15, 37, 40, 50, 53], 'rights': [], 'id': 465, 'score': -6, 'pi': 12, 'grade': 'F', 'gi': 12}
#
# Record # 467 :
#  {'first': 'Peter', 'last': 'Visclosky', 'fullLast': 'Visclosky', 'party': 'd', 'house': 'h', 'state': 'IN', 'control': [9, 10], 'rights': [], 'id': 466, 'score': -2, 'pi': 21, 'grade': 'F', 'gi': 10}
#
# Record # 468 :
#  {'first': 'David', 'last': 'Vitter', 'fullLast': 'Vitter', 'party': 'r', 'house': 's', 'state': 'LA', 'control': [16], 'rights': [61, 72, 73], 'id': 467, 'score': 0, 'pi': 0, 'grade': 'A', 'gi': 0}
#
# Record # 469 :
#  {'first': 'Ann', 'last': 'Wagner', 'fullLast': 'Wagner', 'party': 'r', 'house': 'h', 'state': 'MO', 'control': [], 'rights': [62, 64], 'id': 468, 'score': 2, 'pi': 21, 'grade': 'A', 'gi': 16}
#
# Record # 470 :
#  {'first': 'Tim', 'last': 'Walberg', 'fullLast': 'Walberg', 'party': 'r', 'house': 'h', 'state': 'MI', 'control': [], 'rights': [55, 59, 62, 74, 90, 94, 95], 'id': 469, 'score': 7, 'pi': 21, 'grade': 'A', 'gi': 15}
#
# Record # 471 :
#  {'first': 'Greg', 'last': 'Walden', 'fullLast': 'Walden', 'party': 'r', 'house': 'h', 'state': 'OR', 'control': [], 'rights': [62, 74, 90], 'id': 470, 'score': 3, 'pi': 19, 'grade': 'A', 'gi': 1}
#
# Record # 472 :
#  {'first': 'Mark', 'last': 'Walker', 'fullLast': 'Walker', 'party': 'r', 'house': 'h', 'state': 'NC', 'control': [], 'rights': [62, 64, 75, 94, 95], 'id': 471, 'score': 5, 'pi': 24, 'grade': 'A', 'gi': 16}
#
# Record # 473 :
#  {'first': 'Jackie', 'last': 'Walorski', 'fullLast': 'Walorski', 'party': 'r', 'house': 'h', 'state': 'IN', 'control': [], 'rights': [55, 62, 64, 65, 78, 90, 94], 'id': 472, 'score': 7, 'pi': 22, 'grade': 'A', 'gi': 6}
#
# Record # 474 :
#  {'first': 'Mimi', 'last': 'Walters', 'fullLast': 'Walters', 'party': 'r', 'house': 'h', 'state': 'CA', 'control': [], 'rights': [62], 'id': 473, 'score': 1, 'pi': 20, 'grade': 'A', 'gi': 7}
#
# Record # 475 :
#  {'first': 'Mark', 'last': 'Warner', 'fullLast': 'Warner', 'party': 'd', 'house': 's', 'state': 'VA', 'control': [11], 'rights': [], 'id': 474, 'score': -1, 'pi': 9, 'grade': 'C', 'gi': 1}
#
# Record # 476 :
#  {'first': 'Elizabeth', 'last': 'Warren', 'fullLast': 'Warren', 'party': 'd', 'house': 's', 'state': 'MA', 'control': [8, 11, 22, 34, 42, 44], 'rights': [], 'id': 475, 'score': -6, 'pi': 1, 'grade': 'F', 'gi': 1}
#
# Record # 477 :
#  {'first': 'Debbie', 'last': 'Schultz', 'fullLast': 'Wasserman Schultz', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [10, 14, 15, 50, 53], 'rights': [], 'id': 476, 'score': -5, 'pi': 10, 'grade': 'F', 'gi': 7}
#
# Record # 478 :
#  {'first': 'Maxine', 'last': 'Waters', 'fullLast': 'Waters', 'party': 'd', 'house': 'h', 'state': 'CA', 'control': [10], 'rights': [], 'id': 477, 'score': -1, 'pi': 12, 'grade': 'F', 'gi': 10}
#
# Record # 479 :
#  {'first': 'Bonnie', 'last': 'Coleman', 'fullLast': 'Watson Coleman', 'party': 'd', 'house': 'h', 'state': 'NJ', 'control': [1, 2, 10, 12, 14, 31, 37, 50, 51, 17], 'rights': [], 'id': 478, 'score': -10, 'pi': 7, 'grade': 'F', 'gi': 6}
#
# Record # 480 :
#  {'first': 'Randy', 'last': 'Weber', 'fullLast': 'Weber', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [59, 62, 63, 64, 77, 78, 84, 90, 93, 94, 95, 87, 97], 'id': 479, 'score': 13, 'pi': 6, 'grade': 'A', 'gi': 4}
#
# Record # 481 :
#  {'first': 'Daniel', 'last': 'Webster', 'fullLast': 'Webster', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [57, 59, 62, 64, 90], 'id': 480, 'score': 5, 'pi': 25, 'grade': 'A', 'gi': 9}
#
# Record # 482 :
#  {'first': 'Peter', 'last': 'Welch', 'fullLast': 'Welch', 'party': 'd', 'house': 'h', 'state': 'VT', 'control': [9, 10], 'rights': [], 'id': 481, 'score': -2, 'pi': 22, 'grade': 'D', 'gi': 5}
#
# Record # 483 :
#  {'first': 'Brad', 'last': 'Wenstrup', 'fullLast': 'Wenstrup', 'party': 'r', 'house': 'h', 'state': 'OH', 'control': [], 'rights': [57, 62, 64, 74, 90, 94], 'id': 482, 'score': 6, 'pi': 20, 'grade': 'A', 'gi': 20}
#
# Record # 484 :
#  {'first': 'Bruce', 'last': 'Westerman', 'fullLast': 'Westerman', 'party': 'r', 'house': 'h', 'state': 'AR', 'control': [], 'rights': [55, 57, 62, 63, 64, 65, 67, 74, 75, 78, 90, 94], 'id': 483, 'score': 12, 'pi': 6, 'grade': 'A', 'gi': 5}
#
# Record # 485 :
#  {'first': 'Lynn', 'last': 'Westmoreland', 'fullLast': 'Westmoreland', 'party': 'r', 'house': 'h', 'state': 'GA', 'control': [], 'rights': [55, 62, 63, 64, 90, 93], 'id': 484, 'score': 6, 'pi': 21, 'grade': 'A', 'gi': 16}
#
# Record # 486 :
#  {'first': 'Sheldon', 'last': 'Whitehouse', 'fullLast': 'Whitehouse', 'party': 'd', 'house': 's', 'state': 'RI', 'control': [8, 11, 44], 'rights': [], 'id': 485, 'score': -3, 'pi': 5, 'grade': 'F', 'gi': 5}
#
# Record # 487 :
#  {'first': 'Ed', 'last': 'Whitfield', 'fullLast': 'Whitfield', 'party': 'r', 'house': 'h', 'state': 'KY', 'control': [], 'rights': [62], 'id': 486, 'score': 1, 'pi': 16, 'grade': 'A', 'gi': 6}
#
# Record # 488 :
#  {'first': 'Roger', 'last': 'Wicker', 'fullLast': 'Wicker', 'party': 'r', 'house': 's', 'state': 'MS', 'control': [], 'rights': [61], 'id': 487, 'score': 1, 'pi': 17, 'grade': 'A+', 'gi': 8}
#
# Record # 489 :
#  {'first': 'Roger', 'last': 'Williams', 'fullLast': 'Williams', 'party': 'r', 'house': 'h', 'state': 'TX', 'control': [], 'rights': [57, 59, 62, 63, 64, 90], 'id': 488, 'score': 6, 'pi': 22, 'grade': 'AQ', 'gi': 23}
#
# Record # 490 :
#  {'first': 'Joe', 'last': 'Wilson', 'fullLast': 'Wilson', 'party': 'r', 'house': 'h', 'state': 'SC', 'control': [], 'rights': [59, 62, 64, 71, 90, 94, 95], 'id': 489, 'score': 7, 'pi': 23, 'grade': 'A', 'gi': 19}
#
# Record # 491 :
#  {'first': 'Frederica', 'last': 'Wilson', 'fullLast': 'Wilson', 'party': 'd', 'house': 'h', 'state': 'FL', 'control': [10, 14, 26, 27, 31, 50, 51, 53], 'rights': [], 'id': 490, 'score': -8, 'pi': 7, 'grade': 'F', 'gi': 7}
#
# Record # 492 :
#  {'first': 'Robert', 'last': 'Wittman', 'fullLast': 'Wittman', 'party': 'r', 'house': 'h', 'state': 'VA', 'control': [], 'rights': [55, 57, 59, 62, 63, 64, 65, 71, 90], 'id': 491, 'score': 9, 'pi': 13, 'grade': 'A', 'gi': 1}
#
# Record # 493 :
#  {'first': 'Steve', 'last': 'Womack', 'fullLast': 'Womack', 'party': 'r', 'house': 'h', 'state': 'AR', 'control': [], 'rights': [57, 59, 62, 64, 74, 90], 'id': 492, 'score': 6, 'pi': 23, 'grade': 'A', 'gi': 21}
#
# Record # 494 :
#  {'first': 'Rob', 'last': 'Woodall', 'fullLast': 'Woodall', 'party': 'r', 'house': 'h', 'state': 'GA', 'control': [], 'rights': [78], 'id': 493, 'score': 1, 'pi': 1, 'grade': 'B', 'gi': 19}
#
# Record # 495 :
#  {'first': 'Ron', 'last': 'Wyden', 'fullLast': 'Wyden', 'party': 'd', 'house': 's', 'state': 'OR', 'control': [11], 'rights': [], 'id': 494, 'score': -1, 'pi': 10, 'grade': 'F', 'gi': 7}
#
# Record # 496 :
#  {'first': 'John', 'last': 'Yarmuth', 'fullLast': 'Yarmuth', 'party': 'd', 'house': 'h', 'state': 'KY', 'control': [9, 10, 14, 29, 37, 50], 'rights': [], 'id': 495, 'score': -6, 'pi': 13, 'grade': 'F', 'gi': 13}
#
# Record # 497 :
#  {'first': 'Kevin', 'last': 'Yoder', 'fullLast': 'Yoder', 'party': 'r', 'house': 'h', 'state': 'KS', 'control': [], 'rights': [57, 62, 64, 78, 90], 'id': 496, 'score': 5, 'pi': 26, 'grade': 'A', 'gi': 2}
#
# Record # 498 :
#  {'first': 'Ted', 'last': 'Yoho', 'fullLast': 'Yoho', 'party': 'r', 'house': 'h', 'state': 'FL', 'control': [], 'rights': [62, 63, 75, 94, 97], 'id': 497, 'score': 5, 'pi': 27, 'grade': 'A', 'gi': 22}
#
# Record # 499 :
#  {'first': 'Don', 'last': 'Young', 'fullLast': 'Young', 'party': 'r', 'house': 'h', 'state': 'AK', 'control': [], 'rights': [55, 57, 59, 62, 64, 65, 74, 84, 90], 'id': 498, 'score': 9, 'pi': 14, 'grade': 'A+', 'gi': 10}
#
# Record # 500 :
#  {'first': 'David', 'last': 'Young', 'fullLast': 'Young', 'party': 'r', 'house': 'h', 'state': 'IA', 'control': [], 'rights': [62, 65, 71, 75], 'id': 499, 'score': 4, 'pi': 19, 'grade': 'AQ', 'gi': 20}
#
# Record # 501 :
#  {'first': 'Todd', 'last': 'Young', 'fullLast': 'Young', 'party': 'r', 'house': 'h', 'state': 'IN', 'control': [], 'rights': [57, 62, 64, 90], 'id': 500, 'score': 4, 'pi': 20, 'grade': 'A+', 'gi': 16}
#
# Record # 502 :
#  {'first': 'Lee', 'last': 'Zeldin', 'fullLast': 'Zeldin', 'party': 'r', 'house': 'h', 'state': 'NY', 'control': [48], 'rights': [55, 57, 62, 75, 78], 'id': 501, 'score': 0, 'pi': 2, 'grade': 'A', 'gi': 0}
#
# Record # 503 :
#  {'first': 'Ryan', 'last': 'Zinke', 'fullLast': 'Zinke', 'party': 'r', 'house': 'h', 'state': 'MT', 'control': [], 'rights': [55, 62, 64, 65, 71, 74, 75, 78, 90, 93, 94, 95], 'id': 502, 'score': 12, 'pi': 7, 'grade': 'A-', 'gi': 6}

# %%
from collections import Counter

counter = Counter(str(["grade"] for item in row))

# Separate out the counter to order it correctly when plotting.
data_list = [counter["A"],
             counter["B"],
             counter["C"],
             counter["D"],
             counter["F"]
             ]
grade_tuple = tuple(["A", "B", "C", "D", "F"])

# Assign the data to a plot
plt.plot(data_list)

# Assign labels to the plot
plt.xticks(range(len(grade_tuple[0:5])), grade_tuple)

plt.show()

# Save the plot!
plt.savefig("Grades.png")

# Close figure
plt.clf()

# %% [markdown]
# ### Results
#
# *Further results in results PDF file.*
