# %%
import os
import urllib.request
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot

series = read_csv('2019_nCoV_data.csv', parse_dates=[1])
print(series.head())
series["Confirmed"].plot()
pyplot.show()
# Out:
#    Sno                Date Province/State Country          Last Update  \
# 0    1 2020-01-22 12:00:00          Anhui   China  01/22/2020 12:00:00
# 1    2 2020-01-22 12:00:00        Beijing   China  01/22/2020 12:00:00
# 2    3 2020-01-22 12:00:00      Chongqing   China  01/22/2020 12:00:00
# 3    4 2020-01-22 12:00:00         Fujian   China  01/22/2020 12:00:00
# 4    5 2020-01-22 12:00:00          Gansu   China  01/22/2020 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

series = read_csv('2019_nCoV_data.csv', parse_dates=[1])

autocorrelation_plot(series["Confirmed"])
pyplot.show()

# %%
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

series = read_csv('2019_nCoV_data.csv', parse_dates=[1])

# fit model
model = ARIMA(series["Confirmed"], order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:            D.Confirmed   No. Observations:                 1718
# Model:                 ARIMA(5, 1, 0)   Log Likelihood              -16683.042
# Method:                       css-mle   S.D. of innovations           3989.840
# Date:                Fri, 06 Mar 2020   AIC                          33380.084
# Time:                        15:43:50   BIC                          33418.226
# Sample:                             1   HQIC                         33394.197
#
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              7.835e-07     27.891   2.81e-08      1.000     -54.666      54.666
# ar.L1.D.Confirmed    -0.8255      0.024    -34.682      0.000      -0.872      -0.779
# ar.L2.D.Confirmed    -0.6550      0.030    -21.813      0.000      -0.714      -0.596
# ...

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

series = read_csv('2019_nCoV_data.csv', parse_dates=[1])

X = series["Confirmed"].values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=962.063915, expected=492.000000
# predicted=848.034921, expected=486.000000
# predicted=746.588455, expected=466.000000
# predicted=646.726691, expected=405.000000
# predicted=569.198313, expected=337.000000
# predicted=488.468039, expected=331.000000
# predicted=416.937195, expected=299.000000
# predicted=384.689019, expected=261.000000
# predicted=347.419442, expected=218.000000
# predicted=306.163030, expected=213.000000
# predicted=274.516016, expected=210.000000
# predicted=253.799408, expected=149.000000
# predicted=223.236884, expected=138.000000
# predicted=196.474684, expected=135.000000
# predicted=175.686732, expected=119.000000
# predicted=159.319364, expected=109.000000
# predicted=142.349285, expected=108.000000
# predicted=125.869195, expected=95.000000
# predicted=116.836988, expected=86.000000
# predicted=108.143734, expected=81.000000
# predicted=99.201763, expected=58.000000
# predicted=88.745100, expected=49.000000
# ...
